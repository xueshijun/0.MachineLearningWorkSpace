# %% [markdown]
# # Google+计算文档相似度、提取搭配

# %% [raw]
# 第4章 挖掘Google+：计算文档相似度、提取搭配等 127
# 4.1 概述 128
# 4.2 探索Google+ API 128
# 4.3 TF-IDF简介 138
# 4.4 用TF-IDF查询人类语言数据 145
# 4.5 本章小结 164
# 4.6 推荐练习 165
# 4.7 在线资源 165

# %% [raw]
# pip install google-api-python-client

# %% [markdown]
# # Example 1. 使用Google+ API寻人

# %%
import httplib2
import json
import apiclient.discovery # pip install google-api-python-client

# XXX: Enter any person's name
Q = "Tim O'Reilly"

# XXX: Enter in your API key from  https://code.google.com/apis/console
API_KEY = 'AIzaSyDiXUJAC6FB2CGaQotQHCwOAJlsVa4k7T0' 

service = apiclient.discovery.build('plus', 'v1', http=httplib2.Http(), 
                                    developerKey=API_KEY)

people_feed = service.people().search(query=Q).execute()

print json.dumps(people_feed['items'], indent=1)
# Out:
# [
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/+TimOReilly",
#   "image": {
#    "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/rvotjgCtvvJyAZ0E_wYK_nqWyN8\"",
#   "id": "107033731246200681024",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/112971313488103174611",
#   "image": {
#    "url": "https://lh4.googleusercontent.com/-DHPPpI53zYs/AAAAAAAAAAI/AAAAAAAAAA0/pMnv4IOHinM/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/-tQMA-kdju1h40Q9yqHvt_XGcI8\"",
#   "id": "112971313488103174611",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "TIM O'REILLY",
#   "url": "https://plus.google.com/+TIMOREILLYWRC",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-dOC3TnU5LJk/AAAAAAAAAAI/AAAAAAAAC4o/7EpI7CgLzHs/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/mzB_LaW8Wo-Hz3S5zHmUewTquSY\"",
#   "id": "112630513029834463088",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/117480952841562724952",
#   "image": {
#    "url": "https://lh6.googleusercontent.com/-bpWGUQXAWg0/AAAAAAAAAAI/AAAAAAAAAIs/fCBaH6ldLXU/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/fbrFj4lJ_cpWx9pUUmO6476cZtY\"",
#   "id": "117480952841562724952",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/115665711705516993369",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-ykapO9VSsmU/AAAAAAAAAAI/AAAAAAAAAGE/QjNpGPy5SIc/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/0z-EwRK70ma_SgL89TnXDnNCeg4\"",
#   "id": "115665711705516993369",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/103336854217201973281",
#   "image": {
#    "url": "https://lh4.googleusercontent.com/-J3iV2F3ex4E/AAAAAAAAAAI/AAAAAAAAAOE/2py_-Q9ykVI/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/DlSE9CzFxTBT9ih8O5xpTQ3Y0oI\"",
#   "id": "103336854217201973281",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/102467783732787713430",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-P2nQYJTUZY8/AAAAAAAAAAI/AAAAAAAAAAA/b1obv1Rgmg4/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/RPk8TfaC9CjQlzbaa0EH017EKHg\"",
#   "id": "102467783732787713430",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/106492472890341598734",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-S5DUz4QdL4k/AAAAAAAAAAI/AAAAAAAAAcc/iS9VLgbCTJw/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/DVTuV3GDJ0h4UlM5bybS_d26Fdo\"",
#   "id": "106492472890341598734",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Timothy O'Reilly",
#   "url": "https://plus.google.com/+TimothyOReilly",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-TdJsE6Qsxzg/AAAAAAAAAAI/AAAAAAAAAis/4ltdyyk61mQ/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/3744uM_v9M6mz9icJoOhqz08cPs\"",
#   "id": "107415629896108700526",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName": "Tim O'Reilly",
#   "url": "https://plus.google.com/106680419484587025186",
#   "image": {
#    "url": "https://lh3.googleusercontent.com/-5wQu1d4wF2w/AAAAAAAAAAI/AAAAAAAAAKA/OqGwRWaeVFI/photo.jpg?sz=50"
#   },
#   "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/-a3tNtNGvyUhChUVfGHHROC16Zo\"",
#   "id": "106680419484587025186",
#   "objectType": "person"
#  },
#  {
#   "kind": "plus#person",
#   "displayName":
activity_feed = service.activities().list(
  userId=USER_ID,
  collection='public',
  maxResults='100' # Max allowed per API
).execute()

print json.dumps(activity_feed, indent=1)
# Out:
# {
#  "nextPageToken": "Cg0Q_ozz1tzaywIgACgBEhQIABDQhMzvs53LAhjA9NP5t4vEAhgCIGQo5vK4v52M1bZH",
#  "kind": "plus#activityFeed",
#  "title": "Google+ List of Activities for Collection PUBLIC",
#  "items": [
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Beautiful exposition by Michael Nielsen on how \u201ccognitive media\u201d helps us think and advance our work...",
#    "url": "https://plus.google.com/+TimOReilly/posts/JERRRNmFGmd",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z134gdqj2tynwd0nb23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Toward an exploratory medium for mathematics",
#       "fullImage": {
#        "url": "http://cognitivemedium.com/emm/images/blackboard.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "http://cognitivemedium.com/emm/emm.html",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/qr318pP0ReH9iWULOcT8waZS8ZqXiCQiwUhHPkF9ndO0F0o2jxQWLI2AnWmXQH_CqjY9faJn66YdrvMsXjQg1zkUPvU=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "The world's oldest complete piece of surviving music is the 3400-year-old Hurrian cult hymn. The hymn was found inscribed on clay tablets excavated from the ancient city of Ugarit, in modern-day Syria. Sometime after the hymn was composed, the idea of using notation to record music was lost.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/JERRRNmFGmd",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Beautiful exposition by Michael Nielsen on how \u201ccognitive media\u201d helps us think and advance our work. Starts with music, aims at math. \ufeff",
#     "plusoners": {
#      "totalItems": 14,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z134gdqj2tynwd0nb23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z134gdqj2tynwd0nb23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2016-02-29T16:35:51.826Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/1YgUR6OESAoRP7YZWSTsWrXX7ak\"",
#    "published": "2016-02-29T16:35:51.826Z",
#    "id": "z134gdqj2tynwd0nb23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "A lot of people have asked me to respond to +Paul Graham\u2019s piece about income inequality. Here it is...",
#    "url": "https://plus.google.com/+TimOReilly/posts/hCuJr9NUTx1",
#    "object": {
#     "resharers": {
#      "totalItems": 10,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13nfdpy3y3vw3fzk04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "What Paul Graham Is Missing About Inequality \u2014 What\u2019s The Future of Work?",
#       "fullImage": {
#        "url": "https://cdn-images-1.medium.com/max/800/1*4KDPK6aIpfxnEbGYJ3dcdQ.png",
#        "type": "image/jpeg"
#       },
#       "url": "https://medium.com/the-wtf-economy/what-paul-graham-is-missing-about-inequality-a9f7e1613059#.5nmn0ybn4",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/MZrKyJh0jRgmluE7yrjKabN6dUq0iAT8V0jnSmQc36hQVFiZ280DIMUAyjAjXtiVLk6F-_bstgs5q07iHjzprHUpA3ozCqCE2ec0PJKxWHHAIkMj=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Before he published his essay on inequality, Paul Graham sent it to me for comment. I sent him some quick impressions an\u2026",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/hCuJr9NUTx1",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "A lot of people have asked me to respond to +Paul Graham\u2019s piece about income inequality. Here it is. I suspect that this is just one more step in a long discussion that we will be having.\ufeff",
#     "plusoners": {
#      "totalItems": 90,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13nfdpy3y3vw3fzk04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 21,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13nfdpy3y3vw3fzk04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2016-01-25T19:09:57.357Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/_lUIBT9lOr918otOqfsX0MfMQWQ\"",
#    "published": "2016-01-25T19:09:57.357Z",
#    "id": "z13nfdpy3y3vw3fzk04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "So nice to see @pahlkadot and @codeforamerica recognized by the 2016 David Packard Award for civic e...",
#    "url": "https://plus.google.com/+TimOReilly/posts/bAxNDRFkyXv",
#    "object": {
#     "resharers": {
#      "totalItems": 4,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13wvbdwbqa3u1dqg04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "url": "http://www.jointventure.org/news-and-media/news-releases/1354-code-for-america-founder-jennifer-pahlka-named-recipient-of-joint-venture-s-2016-packard-award",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/4bYvA_glk8nwWFrCaXViKnsBPuNwjdQFmkI7nQpNfyyDhiuqbX2nSY1WUru377L7-X1G3JIfa3bmnLOYq-OEEaG8MbCtfXTbiKC7tzpk=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "fullImage": {
#        "url": "http://www.jointventure.org/images/stories/jennifer-pahlka.jpg",
#        "type": "image/jpeg"
#       },
#       "displayName": "Code for America founder Jennifer Pahlka named recipient of Joint Venture's 2016 Packard Award",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/bAxNDRFkyXv",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "So nice to see @pahlkadot and @codeforamerica recognized by the 2016 David Packard Award for civic entrepreneurship <a href=\"http://www.jointventure.org/news-and-media/news-releases/1354-code-for-america-founder-jennifer-pahlka-named-recipient-of-joint-venture-s-2016-packard-award\">http://www.jointventure.org/news-and-media/news-releases/1354-code-for-america-founder-jennifer-pahlka-named-recipient-of-joint-venture-s-2016-packard-award</a>\ufeff",
#     "plusoners": {
#      "totalItems": 73,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13wvbdwbqa3u1dqg04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 7,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13wvbdwbqa3u1dqg04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2016-01-13T17:09:10.421Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/SMysSM2hkwP4YvD5i7UtAE-FBAs\"",
#    "published": "2016-01-13T17:09:10.421Z",
#    "id": "z13wvbdwbqa3u1dqg04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Reshared Post"
#    },
#    "title": "",
#    "url": "https://plus.google.com/+TimOReilly/posts/ArhrspFuiFV",
#    "object": {
#     "resharers": {
#      "totalItems": 17,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13qfturtniwdfxtu23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "fullImage": {
#        "url": "https://lh3.googleusercontent.com/-fHKAEZWwgfg/VpN7MaXLVTI/AAAAAAAAItc/D2tzvSPJ7QU/w750-h458/16%2B-%2B1",
#        "width": 750,
#        "type": "image/jpeg",
#        "height": 458
#       },
#       "url": "https://plus.google.com/photos/107286020910913706370/albums/6238465363495912209/6238465362003449138",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/-fHKAEZWwgfg/VpN7MaXLVTI/AAAAAAAAItc/D2tzvSPJ7QU/w506-h750/16%2B-%2B1",
#        "type": "image/jpeg"
#       },
#       "content": "1/11/16 - 1",
#       "id": "107286020910913706370.6238465362003449138",
#       "objectType": "photo"
#      }
#     ],
#     "url": "https://plus.google.com/+DanielKeysMoran/posts/CCydLmsPxCY",
#     "actor": {
#      "url": "https://plus.google.com/107286020910913706370",
#      "image": {
#       "url": "https://lh5.googleusercontent.com/-z4oJuLgLnso/AAAAAAAAAAI/AAAAAAAAIo8/YOWAM-Ar7R4/photo.jpg?sz=50"
#      },
#      "displayName": "Daniel Keys Moran",
#      "id": "107286020910913706370",
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "",
#     "plusoners": {
#      "totalItems": 209,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13qfturtniwdfxtu23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 8,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13qfturtniwdfxtu23gcxizetybvpydh/comments"
#     },
#     "id": "z12oxloqqridzbzu222ivbxw4sy1td5c3",
#     "objectType": "activity"
#    },
#    "updated": "2016-01-13T12:21:43.915Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "annotation": "Love this thought!",
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "share",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/B_bExOrf8CkRbmYrtDxqA8ZUr2c\"",
#    "published": "2016-01-13T12:21:43.915Z",
#    "id": "z13qfturtniwdfxtu23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I've been deeply touched by the stories of Syrian refugees in Brandon Stanton's Humans of New York feed...",
#    "url": "https://plus.google.com/+TimOReilly/posts/HSuXAGS2XRP",
#    "object": {
#     "resharers": {
#      "totalItems": 7,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12fct3yvnqhzzef223gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "CLICK HERE to support Let's Give The Gift of a Fresh Start",
#       "fullImage": {
#        "url": "https://c1.iggcdn.com/indiegogo-media-prod-cld/image/upload/c_fill,f_auto,h_630,w_1200/v1450973903/vgsxuqhjfud8dspr9dkn.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.generosity.com/community-fundraising/let-s-give-the-gift-of-a-fresh-start",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/8pxCyPWF87NN4a-XfuBd6TWcqcROAVqBE3vofVKWpvoVjbK2RH3plJDqWbpih1x9Fw5t8K5-UGrFfTml2DgfgdWfDSrd0xCszL7w1mAx_cl4HmJojiStiXKsp6MJlCtnREFZFZmKt0A3KHpxjt8OaiSgjtiqOgqT0dG6W0AgeJoSqXoPqG5JQ1PNGw=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Support 'Let's Give The Gift of a Fresh Start' by donating or sharing today!",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/HSuXAGS2XRP",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I&#39;ve been deeply touched by the stories of Syrian refugees in Brandon Stanton&#39;s Humans of New York feed, and a great way to help is through direct donations to the families involved, through HONY&#39;s Generosity Fundraiser: <br /><br />\ufeff",
#     "plusoners": {
#      "totalItems": 59,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12fct3yvnqhzzef223gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12fct3yvnqhzzef223gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-25T20:17:13.751Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/rnAl-5H8eP0VVCkEpeNejgix1ww\"",
#    "published": "2015-12-25T20:17:13.751Z",
#    "id": "z12fct3yvnqhzzef223gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Excellent MIT Tech Review \u00a0profile of my friend Gary Marcus and his #AI company Geometric Intelligence...",
#    "url": "https://plus.google.com/+TimOReilly/posts/feK5N4HQWQr",
#    "object": {
#     "resharers": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12tsx1odnmme11bb04chl3pvxfbszirt5o/people/resharers"
#     },
#     "url": "https://plus.google.com/+TimOReilly/posts/feK5N4HQWQr",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Excellent MIT Tech Review \u00a0profile of my friend Gary Marcus and his <a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23AI\">#AI</a> company Geometric Intelligence <a href=\"http://www.technologyreview.com/featuredstory/544606/can-this-man-make-ai-more-human/\">http://www.technologyreview.com/featuredstory/544606/can-this-man-make-ai-more-human/</a>\u00a0\ufeff",
#     "plusoners": {
#      "totalItems": 18,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12tsx1odnmme11bb04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12tsx1odnmme11bb04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-20T00:39:08.756Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/VIOwPkaolAJGW9EFyK1yf5KqRFE\"",
#    "published": "2015-12-20T00:39:08.756Z",
#    "id": "z12tsx1odnmme11bb04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I'll be on the Breaking Banks podcast at noon pacific time today, talking about technology and the coming...",
#    "url": "https://plus.google.com/+TimOReilly/posts/G99hHuvBzmu",
#    "object": {
#     "resharers": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cibfzcve2vrkmu23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Breaking Banks | VoiceAmerica\u2122",
#       "fullImage": {
#        "url": "http://www.voiceamerica.com//content/images/host_images/011292/BKing-Shared-wide.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "http://bit.ly/1QZP0v3",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/Lm__iR7otvthmdrgqN3_OvMcvtnnEijx_zLrBAi4rzmJTnTrddC717YJbPcWJ0NjzAGzRZL5j7j7bgTEDiPanQ2JdO4ZCC5DO4LbRpDQmzXWUrpYNWP4InGgJuV-DI-9YRPzLw=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Many industries have been revolutionized by technology in the last decade. Books, Music, TV, Communications, and now it's happening to our money.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/G99hHuvBzmu",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I&#39;ll be on the Breaking Banks podcast at noon pacific time today, talking about technology and the coming disruption of financial markets. This is also the subject of our upcoming Next:Money conference. (<a href=\"http://conferences.oreilly.com/nextcon/money-fintech-us\">http://conferences.oreilly.com/nextcon/money-fintech-us</a>)\ufeff",
#     "plusoners": {
#      "totalItems": 16,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cibfzcve2vrkmu23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cibfzcve2vrkmu23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-17T18:13:16.269Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/z5vLX7vF7jKVoSQu7MoT9pqeyg4\"",
#    "published": "2015-12-17T18:13:16.269Z",
#    "id": "z12cibfzcve2vrkmu23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "This is the fascinating bit: \"the rise of sharing economy companies follows rather than causes the bulk...",
#    "url": "https://plus.google.com/+TimOReilly/posts/QDFaji5eW9Q",
#    "object": {
#     "resharers": {
#      "totalItems": 6,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12lynwi4omexhsoe04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Trying to get a grip on the gig economy - Equitable Growth",
#       "fullImage": {
#        "url": "http://cdn.equitablegrowth.org/wp-content/uploads/2015/12/13130050/AP_81700915726.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "http://equitablegrowth.org/trying-to-get-a-grip-on-the-gig-economy/",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/YexCmMs9_b5obRX1GTEC4FnTmWjDupRwKcbUrSRz98tbnB5Gv23LZ_e2pnNQP4guVLf3IWgQThqf1Y7dFSEWZD5sWbGM0aMJKqHeheeHbTCh1AlLMIszsBeh_p3-mRjFTcBHXEM=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "The data show that independent \"gig economy\" contractors won\u2019t become a major share of workers anytime soon.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/QDFaji5eW9Q",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "This is the fascinating bit: &quot;the rise of sharing economy companies follows rather than causes the bulk of the increase in independent contracting.&quot;\ufeff",
#     "plusoners": {
#      "totalItems": 58,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12lynwi4omexhsoe04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 4,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12lynwi4omexhsoe04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-17T01:32:09.800Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/8NxAeVwHW1oOUldxjOcuYtiwiec\"",
#    "published": "2015-12-17T01:32:09.800Z",
#    "id": "z12lynwi4omexhsoe04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I dreamed last night that Donald Trump was taking people on a tour through a haunted house, and leaving...",
#    "url": "https://plus.google.com/+TimOReilly/posts/NwTNchmzZ6s",
#    "object": {
#     "resharers": {
#      "totalItems": 3,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12yjbd4qmynjx54304chl3pvxfbszirt5o/people/resharers"
#     },
#     "url": "https://plus.google.com/+TimOReilly/posts/NwTNchmzZ6s",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I dreamed last night that Donald Trump was taking people on a tour through a haunted house, and leaving them to pay a big bill afterward. Pretty apt symbolism.\ufeff",
#     "plusoners": {
#      "totalItems": 63,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12yjbd4qmynjx54304chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 23,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12yjbd4qmynjx54304chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-11T12:31:07.101Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/7zOyiV7HXcKoOOlSjUXbst2IkcQ\"",
#    "published": "2015-12-11T12:31:07.101Z",
#    "id": "z12yjbd4qmynjx54304chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Nassau, The Bahamas Airport Travel Advice\n\nIf anyone happens to travel to Nassau, the Bahamas, I thought...",
#    "url": "https://plus.google.com/+TimOReilly/posts/dpQDew7sPbu",
#    "object": {
#     "resharers": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12sepsyuuf0ir3qw04chl3pvxfbszirt5o/people/resharers"
#     },
#     "url": "https://plus.google.com/+TimOReilly/posts/dpQDew7sPbu",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "<b>Nassau, The Bahamas Airport Travel Advice</b><br /><br />If anyone happens to travel to Nassau, the Bahamas, I thought I&#39;d pass on a travel tip. \u00a0They insist that you get to the airport 3 hours before your flight, and that turns out to be completely unnecessary. \u00a0I tried to target 90 minutes, just to be safe, but the event organizers for the event I was at hustled me out to get there about two hours before the flight.\u00a0<br /><br />It took me no more than ten minutes to get through the entire process - security AND US Customs, so I ended up at the gate for the better part of two hours. \u00a0<br /><br />Your mileage may vary - I have global entry, but even without that, there was no line. \u00a0However, I was told at the airport that it was particularly light, and that if you have to check baggage or check in at the airport, the check in desks close an hour before the flight. \u00a0But if you have a boarding pass, and aren&#39;t checking luggage, I&#39;d bet an hour before the flight is easily sufficient.<br /><br />I suppose that it is worth checking how many other flights are going out about the same time as yours. At my hotel, they listed all the flights, so it would be easy to see. I was traveling on the first flight out on a Saturday morning, and there may be other times that are much more crowded. \u00a0\ufeff",
#     "plusoners": {
#      "totalItems": 17,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12sepsyuuf0ir3qw04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 3,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12sepsyuuf0ir3qw04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-05T18:02:02.347Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/jP0SUoNv1BuvB2Ff5sAPb90KfBw\"",
#    "published": "2015-12-05T18:02:02.347Z",
#    "id": "z12sepsyuuf0ir3qw04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Amazing story about digital transformation http://www.codeforamerica.org/blog/2015/11/30/a-new-approach...",
#    "url": "https://plus.google.com/+TimOReilly/posts/BRmKh2ycaPe",
#    "object": {
#     "resharers": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13iytgh2oiwexety23gcxizetybvpydh/people/resharers"
#     },
#     "url": "https://plus.google.com/+TimOReilly/posts/BRmKh2ycaPe",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Amazing story about digital transformation <a href=\"http://www.codeforamerica.org/blog/2015/11/30/a-new-approach-to-procuring-government-technology-in-california/\">http://www.codeforamerica.org/blog/2015/11/30/a-new-approach-to-procuring-government-technology-in-california/</a> &quot;Government Procurement: A New Hope\u201d :-)<br /><br />&quot;This fall, I started working with a small, cross-agency team at the California state capital in Sacramento to see how practical and realistic it would be to move from a traditional, large, and typically risky RFP for an entire system to a set of smaller RFPs, explicitly requiring user-centered, agile, iterative development. With this would come a fundamental change: from procuring or buying a set solution to building California\u2019s ability to understand, direct, and control the critical technology needed for government to do its job well....<br /><br />&quot;But why would a Child Welfare System in particular be a good choice for this new approach? Child welfare services personnel in California investigate nearly half a million reports of severe maltreatment and life-threatening neglect to children a year. Of those half a million, around 80,000 reports are confirmed annually, 30,000 children must be removed from their homes, and at any time almost 100,000 children are living in foster care for their protection or live with their parents under close county protective supervision. The Child Welfare System was the perfect choice for a new approach because it\u2019s too important to fail.&quot;\ufeff",
#     "plusoners": {
#      "totalItems": 31,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13iytgh2oiwexety23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13iytgh2oiwexety23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-05T15:05:01.850Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/qRfKoju18e-W5KGdkI9FgLoX_Fo\"",
#    "published": "2015-12-05T15:05:01.850Z",
#    "id": "z13iytgh2oiwexety23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Cool use of Minecraft for conservation!",
#    "url": "https://plus.google.com/+TimOReilly/posts/FQqNU2i67BH",
#    "object": {
#     "resharers": {
#      "totalItems": 8,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mclqivnnad352q23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Minecraft: We Are the Rangers - Animals",
#       "fullImage": {
#        "url": "http://s.radar.oreilly.com/wp-files/7/2015/10/wearerangers_screen-1024x668.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "http://animals.oreilly.com/we-are-the-rangers-minecraft/",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/mZcr-KAnYyg4yuMbkgpKinuaph_q6WEHvmnhZY7t0VZ6Egh86Iwfn5qGg2gOiaNiATl3Hk0sQjqxpUXTgstNAEHj8kSapd8uDojTvO7zxTJY1NyyIeAb-D4tyoRn-g=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Minecraft meets Instant Wild: Introducing an African wildlife conservancy game, where players are rangers, protecting elephants, lions, rhinos, and more.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/FQqNU2i67BH",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Cool use of Minecraft for conservation!\ufeff",
#     "plusoners": {
#      "totalItems": 31,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mclqivnnad352q23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 7,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mclqivnnad352q23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-12-01T01:40:13.027Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/gBCSjunvT7SvegTYgioDQFgNQxc\"",
#    "published": "2015-12-01T01:40:13.027Z",
#    "id": "z13mclqivnnad352q23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Safari is O'Reilly's subscription access program - thousands of hours of video (including full video...",
#    "url": "https://plus.google.com/+TimOReilly/posts/ZzxXrnzbTVd",
#    "object": {
#     "resharers": {
#      "totalItems": 6,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mf5zbspfospdi504chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Safari - Celebrate with 50% off",
#       "fullImage": {
#        "url": "https://www.safaribooksonline.com/static/corp/img/safari-og.png",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.safaribooksonline.com/public/cm2015/?utm_source=twittersocial&utm_medium=D1TW12AM",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/S81xV3t-NmkqsvU5fGeSwp_Eo7lxyk02ZYZeMIwzqcVrZYEnRK7Ng9PupHhgN7qErZo7UiUCmsZp_gv0YfcJ1T1jbShLF7A0swph9uu2gQ=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Cyber Monday 2015",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/ZzxXrnzbTVd",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Safari is O&#39;Reilly&#39;s subscription access program - thousands of hours of video (including full video from many O&#39;Reilly conferences) and tens of thousands of books from O&#39;Reilly and many other publishers. \u00a0Check out our cyber-Monday offer: $199/year for complete access.\ufeff",
#     "plusoners": {
#      "totalItems": 22,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mf5zbspfospdi504chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13mf5zbspfospdi504chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-30T17:31:50.709Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/6uwtFkrkQLzAvhhp-tdM7gDms6s\"",
#    "published": "2015-11-30T17:31:50.709Z",
#    "id": "z13mf5zbspfospdi504chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "John Oliver: \"There was only one time in American history when the fear of refugees wiping everyone ...",
#    "url": "https://plus.google.com/+TimOReilly/posts/RVdwAVegYsu",
#    "object": {
#     "resharers": {
#      "totalItems": 42,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12adhrjdriid1i4m04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "John Oliver makes the complete, unvarnished case for accepting Syrian refugees",
#       "fullImage": {
#        "url": "http://api.theweek.com/sites/default/files/styles/tw_image_6_4/public/Screen%20Shot%202015-11-23%20at%203.29.52%20AM.jpg?itok=QUzXn5XI",
#        "type": "image/jpeg"
#       },
#       "url": "http://theweek.com/speedreads/590431/john-oliver-makes-complete-unvarnished-case-accepting-syrian-refugees",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/8lTbwkQJzTiOkR60zV12FeQOtdIogsjS6UIhWNy-9HT5XdzM2cqqK2H4n8tJxazQUmWKfdtYL2F0XHeMsyfROroByRsuBbBfVsCJy08uaXIp7llFav7QApQNYtiZJS6bGz-SwK3SfzkFwTD1Y1z4yL67l-r-EMnIuMxg6UANOXdEZ-7_UiaaS2g3K0yffxWcqS32WpcC6Q=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "John Oliver has the perfect (or really, perfectly terrible) response when your elderly relatives start sniping at you during Thanksgiving dinner. \"When your grandmother is complaining about your new piercing, saying your generation is terrible, simply reply, 'Okay, Nana, but at least we didn't send Jews back to Europe in 1939.' Then break off a turkey leg, drop it like a microphone, and you've just won the dinner.\" Oliver is talking specifically ...",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/RVdwAVegYsu",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "John Oliver: &quot;There was only one time in American history when the fear of refugees wiping everyone out did actually come true...&quot;\u201c...and we\u2019ll be celebrating it on Thursday.\u201d<br /><br />That&#39;s maybe the best line, but there&#39;s lots of substance here too. Well worth watching.\ufeff",
#     "plusoners": {
#      "totalItems": 226,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12adhrjdriid1i4m04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 28,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12adhrjdriid1i4m04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-23T20:01:59.500Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/wYv5L9s8pmgDsikOGhLyW6Tzf8o\"",
#    "published": "2015-11-23T20:01:59.500Z",
#    "id": "z12adhrjdriid1i4m04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Video learning paths have been a huge hit on oreilly.com. They are available on @safari too.",
#    "url": "https://plus.google.com/+TimOReilly/posts/S7sE9MLq5hw",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z123ffbj2x21t55oq04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "content": "Safari",
#       "url": "http://www.safaribooksonline.com/list/oreilly-learning-paths",
#       "displayName": "List: O'Reilly Learning Paths: Safari",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/S7sE9MLq5hw",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Video learning paths have been a huge hit on <a href=\"http://oreilly.com\">oreilly.com</a>. They are available on @safari too.\ufeff",
#     "plusoners": {
#      "totalItems": 18,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z123ffbj2x21t55oq04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 0,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z123ffbj2x21t55oq04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-19T15:24:44.415Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/FVdkL7Wokakf7iFd2P20kfqtavQ\"",
#    "published": "2015-11-19T15:24:44.415Z",
#    "id": "z123ffbj2x21t55oq04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Here are the 2016 @codeforamerica Fellowship partner cities. Can\u2019t wait to see the impact of these projects...",
#    "url": "https://plus.google.com/+TimOReilly/posts/MwkbTgqo51J",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12swnsynm2ih5avx23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "The 2016 CfA Fellowship | Code for America",
#       "fullImage": {
#        "url": "http://codeforamerica.org//media/images/cities/cities_header.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.codeforamerica.org/governments/2016-announcement",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/_j91BS8IvO-MGmH2EB_tesHvkusKUiT3qh1iRkhzl9FrQf7u5tdVOM3VtYPexhmem4fDZnahgNGwkYZmaomsnxsuMd4dG7ilXezqIKtqBAE=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Code for America is working towards a government by the people, for the people, that works in the 21st century. We are a 501(c)3 non-profit that helps residents and governments harness technology to solve community problems.",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/MwkbTgqo51J",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Here are the 2016 @codeforamerica Fellowship partner cities. Can\u2019t wait to see the impact of these projects!\ufeff",
#     "plusoners": {
#      "totalItems": 31,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12swnsynm2ih5avx23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12swnsynm2ih5avx23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-18T00:31:17.114Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/cnzW279OD3KPnV_f5RVWtIhOKJA\"",
#    "published": "2015-11-18T00:31:17.114Z",
#    "id": "z12swnsynm2ih5avx23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Absolutely brilliant piece about complexity, public policy, and business From #NextEconomy speaker Esko...",
#    "url": "https://plus.google.com/+TimOReilly/posts/VjsAqUeGVA4",
#    "object": {
#     "resharers": {
#      "totalItems": 36,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z122utgjct3ijbu5f04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Complexity \u2014 What\u2019s The Future of Work?",
#       "fullImage": {
#        "url": "https://cdn-images-1.medium.com/max/800/1*YQHbt5QcIk8JGazBQFjA3Q.jpeg",
#        "type": "image/jpeg"
#       },
#       "url": "http://bit.ly/1MAL9VW",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/Su6SzV-hTJfjLJ05AUK3pVtqlyYTk7ucfZuk9JIqTGAWMquvhpyg1wFhbrZxS8TRHZL-gwZyd4yKtm8RvK69-20tXdpoy6l-oGDv9NCOPXSSlZETjw=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "We often think that what materializes in the world is chosen by some individuals, the leaders. If good things happen and\u2026",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/VjsAqUeGVA4",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "Absolutely brilliant piece about complexity, public policy, and business From <a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23NextEconomy\">#NextEconomy</a> speaker Esko Kilpi. He is such a fresh business thinker. Every time I read his stuff, I come away looking at the world differently.\ufeff",
#     "plusoners": {
#      "totalItems": 88,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z122utgjct3ijbu5f04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z122utgjct3ijbu5f04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-11-11T16:57:37.665Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/7_dci24VAkNu10GXnPAhgwt8utE\"",
#    "published": "2015-11-11T16:57:37.665Z",
#    "id": "z122utgjct3ijbu5f04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "Portable benefits tied to the worker, not the company, are key to rethinking the social safety net for...",
#    "url": "https://plus.google.com/+TimOReilly/posts/TJMVfMWgeX4",
#    "object": {
#     "resharers": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13pzrpivoyhibbgx04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Common ground for independent workers",
#       "fullImage": {
#        "url": "https://cdn-images-1.medium.com/max/800/1*dmbNkD5D-u45r44go_cf0g.png",
#        "type": "image/jpeg"
#       },
#       "url": "https://medium.com/@principles/common-ground-for-independent-workers-83f3fbcf548f",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/wLrITb5EIxZ-KCpuTm0C9kAfkUQ6S682Y94Vvo9nMuKhfTN3YrfZc2neUECc648SU5lw-rFYLKNqDXuxIJhy8RYpb6AwivrwprpAGevZ6FLfhQWQ=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Principles for delivering a stable and flexible safety net for all types of work",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/TJMVfMWgeX4",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
# ...
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/56PVZ87o6wmkVPUOvBOvpinSoaI\"",
#    "published": "2015-03-19T02:29:57.822Z",
#    "id": "z12ljdvifneoxrj5l04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "9 days until SXSW Interactive: White House tech wiz Mikey Dickerson joins @pahlkadot\u00a0on March 16 to ...",
#    "url": "https://plus.google.com/+TimOReilly/posts/jnoHbcFx23r",
#    "object": {
#     "resharers": {
#      "totalItems": 9,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12kvnwooxrhe5ujz04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "\nHow Government Fails and How You Can Fix It\n\n|\nSXSW 2015 Event Schedule\n",
#       "fullImage": {
#        "url": "http://img.sxsw.com/2015/presenters/452845.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "http://schedule.sxsw.com/2015/events/event_IAP996688",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/ikJYnW6NBENp43aGgtlt_FMKBvHInXTFnq_DIQVbTj17XqghiyOqHGN61svqjSAHfrxkEPA5jxDrZaas6Z8=w120-h120",
#        "width": 120,
#        "type": "image/jpeg",
#        "height": 120
#       },
#       "content": "It's not just healthcare.gov. Why do US taxpayers still pay hundreds of millions of dollars for websites that should cost thousands (and often don\u2019t work)? The real reasons may ...",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/jnoHbcFx23r",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "9 days until SXSW Interactive: White House tech wiz Mikey Dickerson joins @pahlkadot\u00a0on March 16 to talk about How Government Fails and How You Can Fix It. \u00a0<br /><br />It&#39;s not just <a href=\"http://healthcare.gov\">healthcare.gov</a> (which Mikey helped fix). Why do US taxpayers still pay hundreds of millions of dollars for websites that should cost thousands (and often don\u2019t work)? The real reasons may surprise you. For government to work in the 21st century, it must become competent \u2013 even great \u2013 at digital. The bad news is that no one is going to do that for us. It\u2019s the job of the American people. The good news is that it\u2019s now possible, and the most rewarding work you\u2019ll ever do.<br /><br /><a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23sxsw\">#sxsw</a> <a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23usds\">#usds</a>\ufeff",
#     "plusoners": {
#      "totalItems": 30,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12kvnwooxrhe5ujz04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 4,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12kvnwooxrhe5ujz04chl3pvxfbszirt5o/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-03-06T17:40:43.021Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/gSiJDI3Og1s55K5m6B_xlIA-NF0\"",
#    "published": "2015-03-06T17:40:43.021Z",
#    "id": "z12kvnwooxrhe5ujz04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "I like +Nancy Lublin's pineapple hack. #LeanInTogether",
#    "url": "https://plus.google.com/+TimOReilly/posts/MviCUXwhunp",
#    "object": {
#     "resharers": {
#      "totalItems": 2,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13ctphydrz5zb3fx23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "A surprising solution to sexism? PINEAPPLES!",
#       "fullImage": {
#        "url": "http://m.c.lnkd.licdn.com/mpr/mpr/AAEAAQAAAAAAAALxAAAAJGRkNDNkNTIwLTgwN2EtNGZkZC1iN2I4LWI3OGNhZjYxMjIxNg.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "https://www.linkedin.com/pulse/surprising-solution-sexism-pineapples-nancy-lublin",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/XoYnrG39IbYvzvnhHEZUgL7dcxhPPExbXq9Jlt94zc_QndRuCKJdunbB4ttUvO7jY64kroH0dQDKJmf7IGO_n-KU4kk8ShNMeBsPO8-EGVGrC3SrBTQfrOZy91jZCOyYZ25xS4ycMtIoihyzRJZgzRdRqErlQ4qcr-UWvg=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Guys often think sexist comments aren't cool but don't speak up. If the goal is for all people to view the potential of girls and women in new bold ways, then we need those dude voices! That includes boys and men--and not just as targets of awareness campaigns, but as leaders.Guys are more likely to shut down sexist comments when (a) they\u2019re supported by other guys (b) they have a clear and easy tactic to use and (c) its fun, not lame.One idea? P...",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/MviCUXwhunp",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I like +Nancy Lublin&#39;s pineapple hack. <a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23LeanInTogether\">#LeanInTogether</a>\ufeff",
#     "plusoners": {
#      "totalItems": 43,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13ctphydrz5zb3fx23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 10,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13ctphydrz5zb3fx23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-03-06T15:08:44.374Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/Dh8BDC9qTpy71D1XKequXU8E454\"",
#    "published": "2015-03-06T15:08:44.374Z",
#    "id": "z13ctphydrz5zb3fx23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Reshared Post"
#    },
#    "title": "I'll be moderating a great panel at \u00a0#sparksummit East in two weeks. Hope to see you there \u00a0http://goo.gl...",
#    "url": "https://plus.google.com/+TimOReilly/posts/SbtKc21oBEm",
#    "object": {
#     "resharers": {
#      "totalItems": 1,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12fid5bfwfnin1wt04chl3pvxfbszirt5o/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "I'll be moderating a great panel at \u00a0#sparksummit East in two weeks. Hope to see you there \u00a0http://goo.gl/L75OKP \u00a0",
#       "fullImage": {
#        "url": "https://lh4.googleusercontent.com/-xSblWM72nhA/VPXRcG8eTLI/AAAAAAAAECE/PdrG7RGUH7M/w1526-h490/spark-summit-east-panel.jpg",
#        "width": 1526,
#        "type": "image/jpeg",
#        "height": 490
#       },
#       "url": "https://plus.google.com/photos/112088286330198500759/albums/6122029543378731281/6122029549310856370",
#       "image": {
#        "url": "https://lh4.googleusercontent.com/-xSblWM72nhA/VPXRcG8eTLI/AAAAAAAAECE/PdrG7RGUH7M/w506-h750/spark-summit-east-panel.jpg",
#        "type": "image/jpeg"
#       },
#       "content": "spark-summit-east-panel.jpg",
#       "id": "112088286330198500759.6122029549310856370",
#       "objectType": "photo"
#      }
#     ],
#     "url": "https://plus.google.com/112088286330198500759/posts/cgKsQYAWbxW",
#     "actor": {
#      "url": "https://plus.google.com/112088286330198500759",
#      "image": {
#       "url": "https://lh3.googleusercontent.com/-hptl1QBFylM/AAAAAAAAAAI/AAAAAAAACnc/zDGsijlt91k/photo.jpg?sz=50"
#      },
#      "displayName": "ben lorica",
#      "id": "112088286330198500759",
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "I&#39;ll be moderating a great panel at \u00a0<a rel=\"nofollow\" class=\"ot-hashtag\" href=\"https://plus.google.com/s/%23sparksummit\">#sparksummit</a> East in two weeks. Hope to see you there \u00a0<a href=\"http://goo.gl/L75OKP\">http://goo.gl/L75OKP</a> \u00a0\ufeff",
#     "plusoners": {
#      "totalItems": 18,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12fid5bfwfnin1wt04chl3pvxfbszirt5o/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 3,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12fid5bfwfnin1wt04chl3pvxfbszirt5o/comments"
#     },
#     "id": "z12dsvxw4x2zsddyp04ce3b4htvlwf25w1k",
#     "objectType": "activity"
#    },
#    "updated": "2015-03-05T03:34:06.900Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "share",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/YAGwN96199HHcNmDTC6rHOgsR6Y\"",
#    "published": "2015-03-05T03:34:06.900Z",
#    "id": "z12fid5bfwfnin1wt04chl3pvxfbszirt5o"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "There are two kinds of interviews: those that quote you literally, and those that distill the essence...",
#    "url": "https://plus.google.com/+TimOReilly/posts/MNAykeY4oCJ",
#    "object": {
#     "resharers": {
#      "totalItems": 21,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13bytzaewmhgrs3t23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Tim O\u2019Reilly: Silicon Valley is massively underestimating the impact of IoT (interview)",
#       "fullImage": {
#        "url": "http://i1.wp.com/venturebeat.com/wp-content/uploads/2015/03/437014292_81c998f22e_b.jpg?fit=780%2C9999",
#        "type": "image/jpeg"
#       },
#       "url": "http://venturebeat.com/2015/03/04/tim-oreilly-silicon-valley-is-massively-underestimating-the-impact-of-iot-interview",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/UOBDYM_nvKZx0pbJaYp9Yv-gCaRSielhfOYT9fSU-NS_aUiUaWG5KhhyB236Xm5cNgBiyCZP2GvFGF1e_A2Z48ilaJlzJOfH9tDP-QwZ-hYS23eNS64SUu_wqraiQyvOC61GAgFg-kQXCdiOtduFLeegHDxD=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "Smart forks. Smart tennis rackets. Smart toothbrushes. Smart teddy bears. Smart fitness bands. The Internet of Things hype is inspiring an endless stream of connected gadgets that light up Kickstar...",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/MNAykeY4oCJ",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "There are two kinds of interviews: those that quote you literally, and those that distill the essence of what you said, perfectly. Chris O&#39;Brien&#39;s @venturebeat interview with me did the latter, and nailed it. \u00a0Just about the only time I can think of a flawless transcript of what was meant rather than just what was said.\ufeff",
#     "plusoners": {
#      "totalItems": 73,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13bytzaewmhgrs3t23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 5,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z13bytzaewmhgrs3t23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-03-04T16:03:53.169Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/EnQGNCwx0jQ2NXl9ZKMs-2I1RmE\"",
#    "published": "2015-03-04T16:03:53.169Z",
#    "id": "z13bytzaewmhgrs3t23gcxizetybvpydh"
#   },
#   {
#    "kind": "plus#activity",
#    "provider": {
#     "title": "Google+"
#    },
#    "title": "What a great read! \u00a0@neilhimself explains why our future depends on libraries, reading and daydreaming...",
#    "url": "https://plus.google.com/+TimOReilly/posts/2hPChcMptgQ",
#    "object": {
#     "resharers": {
#      "totalItems": 70,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cstmjykyfcp4ke23gcxizetybvpydh/people/resharers"
#     },
#     "attachments": [
#      {
#       "displayName": "Neil Gaiman: Why our future depends on libraries, reading and daydreaming",
#       "fullImage": {
#        "url": "http://static.guim.co.uk/sys-images/BOOKS/Pix/pictures/2013/10/15/1381845012962/Neil-Gaiman-013.jpg",
#        "type": "image/jpeg"
#       },
#       "url": "http://www.theguardian.com/books/2013/oct/15/neil-gaiman-future-libraries-reading-daydreaming",
#       "image": {
#        "url": "https://lh3.googleusercontent.com/proxy/cR2EcpXMu3xxljNv8c5k18VxJTPhKrSkbxJfKDjR-jjFrK_-Kb1Aj1DxYdt6ZhGdquD1G7KPY3-T2_vKvNo9pUCnMoYfBcg8UR54wpW3OI6AOckPgaKactC2H-V77T8d90OTGr3uZIC6hm6nt1z5fFcemQ=w506-h910",
#        "width": 506,
#        "type": "image/jpeg",
#        "height": 910
#       },
#       "content": "A lecture explaining why using our imaginations, and providing for others to use theirs, is an obligation for all citizens",
#       "objectType": "article"
#      }
#     ],
#     "url": "https://plus.google.com/+TimOReilly/posts/2hPChcMptgQ",
#     "actor": {
#      "verification": {
#       "adHocVerified": "PASSED"
#      }
#     },
#     "content": "What a great read! \u00a0@neilhimself explains why our future depends on libraries, reading and daydreaming. I\u00a0love the bit about China! And I am horrified by the bit about prisons.\ufeff",
#     "plusoners": {
#      "totalItems": 133,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cstmjykyfcp4ke23gcxizetybvpydh/people/plusoners"
#     },
#     "replies": {
#      "totalItems": 3,
#      "selfLink": "https://www.googleapis.com/plus/v1/activities/z12cstmjykyfcp4ke23gcxizetybvpydh/comments"
#     },
#     "objectType": "note"
#    },
#    "updated": "2015-03-03T05:20:45.800Z",
#    "actor": {
#     "url": "https://plus.google.com/107033731246200681024",
#     "image": {
#      "url": "https://lh4.googleusercontent.com/-J8nmMwIhpiA/AAAAAAAAAAI/AAAAAAADdg4/68r2hyFUgzI/photo.jpg?sz=50"
#     },
#     "displayName": "Tim O'Reilly",
#     "id": "107033731246200681024",
#     "verification": {
#      "adHocVerified": "PASSED"
#     }
#    },
#    "access": {
#     "items": [
#      {
#       "type": "public"
#      }
#     ],
#     "kind": "plus#acl",
#     "description": "Public"
#    },
#    "verb": "post",
#    "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/oI2f3m-EVyXvSJiU2SpiJxYuIyM\"",
#    "published": "2015-03-03T05:20:45.800Z",
#    "id": "z12cstmjykyfcp4ke23gcxizetybvpydh"
#   }
#  ],
#  "updated": "2016-02-29T16:35:51.826Z",
#  "etag": "\"4OZ_Kt6ujOh1jaML_U6RM6APqoE/uVZO8GNH06jP6s31tHwwWU-fYVU\""
# }

# %% [markdown]
# # Example 4.通过去除html标签清理Google+内容中的HTML,并将HTML实体还原为纯文本表示

# %% [raw]
# pip install nltk beautifulsoup4

# %%
from nltk import clean_html
from bs4 import BeautifulSoup

# clean_html removes tags and BeautifulStoneSoup converts HTML entities
s=activity_feed['items'][0]['object']['content']
print s

print #To remove HTML markup, use BeautifulSoup's get_text() function
#print clean_html(activity_feed['items'][0]['object']['content'])
soup = BeautifulSoup(s, 'html.parser')
print soup.get_text()
# Out:
# Beautiful exposition by Michael Nielsen on how “cognitive media” helps us think and advance our work. Starts with music, aims at math. ﻿
#
# Beautiful exposition by Michael Nielsen on how “cognitive media” helps us think and advance our work. Starts with music, aims at math. ﻿

# %% [markdown]
# # Example 5.对多页的Google+“动态”进行循环,并从记录中提取出纯净的文本

# %%
import os
import httplib2
import json
import apiclient.discovery
from bs4 import BeautifulSoup
from nltk import clean_html

USER_ID = '107033731246200681024' # Tim O'Reilly

# XXX: Re-enter your API_KEY from  https://code.google.com/apis/console 
# if not currently set
API_KEY = 'AIzaSyDiXUJAC6FB2CGaQotQHCwOAJlsVa4k7T0' 
MAX_RESULTS = 200 # Will require multiple requests

service = apiclient.discovery.build('plus', 'v1', http=httplib2.Http(), developerKey=API_KEY)

activity_feed = service.activities().list(
      userId=USER_ID,
      collection='public',
      maxResults='100' # Max allowed per request
)

activity_results = []

while activity_feed != None and len(activity_results) < MAX_RESULTS:
  activities = activity_feed.execute()

  if 'items' in activities:
    for activity in activities['items']:
      if activity['object']['objectType'] == 'note' and activity['object']['content'] != '':
            
        title = BeautifulSoup(activity['title'], 'html.parser') 
        activity['title'] = title.get_text()
        content = BeautifulSoup(activity['object']['content'], 'html.parser') 
        activity['object']['content'] = content.get_text()
        activity_results += [activity]

  # list_next requires the previous request and response objects
  activity_feed = service.activities().list_next(activity_feed, activities)

# Write the output to a file for convenience

f = open(''.join(['resources','/', 'ch04-googleplus','/',USER_ID + '.json']), 'w')
f.write(json.dumps(activity_results, indent=1))
f.close()

print str(len(activity_results)), "activities written to", f.name
# Out:
# 248 activities written to resources/ch04-googleplus/107033731246200681024.json

# %% [markdown]
# # Example 6. 样本数据结构

# %%
corpus = { 
 'a' : "Mr. Green killed Colonel Mustard in the study with the candlestick. \
Mr. Green is not a very nice fellow.",
 'b' : "Professor Plum has a green plant in his study.",
 'c' : "Miss Scarlett watered Professor Plum's green plant while he was away \
from his office last week."
}
terms = {
 'a' : [ i.lower() for i in corpus['a'].split() ],
 'b' : [ i.lower() for i in corpus['b'].split() ],
 'c' : [ i.lower() for i in corpus['c'].split() ]
 }

# %% [markdown]
# # Example 7. 在样本数据上计算TF-IDF

# %%
from math import log

# XXX: Enter in a query term from the corpus variable
QUERY_TERMS = ['mr.', 'green']

def tf(term, doc, normalize=True):
    doc = doc.lower().split()
    if normalize:
        return doc.count(term.lower()) / float(len(doc))
    else:
        return doc.count(term.lower()) / 1.0


def idf(term, corpus):
    num_texts_with_term = len([True for text in corpus if term.lower() in text.lower().split()])

    # tf-idf calc involves multiplying against a tf value less than 0, so it's
    # necessary to return a value greater than 1 for consistent scoring. 
    # (Multiplying two values less than 1 returns a value less than each of 
    # them.)

    try:
        return 1.0 + log(float(len(corpus)) / num_texts_with_term)
    except ZeroDivisionError:
        return 1.0


def tf_idf(term, doc, corpus):
    return tf(term, doc) * idf(term, corpus)


corpus = \
    {'a': 'Mr. Green killed Colonel Mustard in the study with the candlestick. \
Mr. Green is not a very nice fellow.',
     'b': 'Professor Plum has a green plant in his study.',
     'c': "Miss Scarlett watered Professor Plum's green plant while he was away \
from his office last week."}

for (k, v) in sorted(corpus.items()):
    print k, ':', v
print
    
# Score queries by calculating cumulative tf_idf score for each term in query

query_scores = {'a': 0, 'b': 0, 'c': 0}
for term in [t.lower() for t in QUERY_TERMS]:
    for doc in sorted(corpus):
        print 'TF(%s): %s' % (doc, term), tf(term, corpus[doc])
    print 'IDF: %s' % (term, ), idf(term, corpus.values())
    print

    for doc in sorted(corpus):
        score = tf_idf(term, corpus[doc], corpus.values())
        print 'TF-IDF(%s): %s' % (doc, term), score
        query_scores[doc] += score
    print

print "Overall TF-IDF scores for query '%s'" % (' '.join(QUERY_TERMS), )
for (doc, score) in sorted(query_scores.items()):
    print doc, score
# Out:
# a : Mr. Green killed Colonel Mustard in the study with the candlestick. Mr. Green is not a very nice fellow.
# b : Professor Plum has a green plant in his study.
# c : Miss Scarlett watered Professor Plum's green plant while he was away from his office last week.
#
# TF(a): mr. 0.105263157895
# TF(b): mr. 0.0
# TF(c): mr. 0.0
# IDF: mr. 2.09861228867
#
# TF-IDF(a): mr. 0.220906556702
# TF-IDF(b): mr. 0.0
# TF-IDF(c): mr. 0.0
#
# TF(a): green 0.105263157895
# TF(b): green 0.111111111111
# TF(c): green 0.0625
# IDF: green 1.0
#
# TF-IDF(a): green 0.105263157895
# TF-IDF(b): green 0.111111111111
# TF-IDF(c): green 0.0625
#
# Overall TF-IDF scores for query 'mr. green'
# a 0.326169714597
# b 0.111111111111
# c 0.0625

# %% [markdown]
# # Example 8. 用NLTK解析Google+ data

# %%
# Explore some of NLTK's functionality by exploring the data. 
# Here are some suggestions for an interactive interpreter session.

import nltk

# Download ancillary nltk packages if not already installed
nltk.download('stopwords')

all_content = " ".join([ a['object']['content'] for a in activity_results ])

# Approximate bytes of text
print len(all_content)

tokens = all_content.split()
text = nltk.Text(tokens)
text.concordance("open")

text.collocations()

fdist = text.vocab()
fdist["open"]
fdist["source"]
fdist["web"]
fdist["2.0"]

# Number of words in the text
len(tokens)

# Number of unique words in the text

len(fdist.keys())

# Common words that aren't stopwords
[w for w in fdist.keys()[:100] \
   if w.lower() not in nltk.corpus.stopwords.words('english')]

# Long words that aren't URLs
[w for w in fdist.keys() if len(w) > 15 and not w.startswith("http")]

# Number of URLs
len([w for w in fdist.keys() if w.startswith("http")])

# Enumerate the frequency distribution
for rank, word in enumerate(fdist): 
    print rank, word, fdist[word]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 132719
# Displaying 19 of 19 matches:
#  I'm proud to be a signatory to this open letter calling for this key policy i
# st, I've focused a lot on areas like open source software and the implications
# opic at greater length in my article Open Data and Algorithmic Regulation: htt
# cessful participatory projects, from open source software to wikis to social m
# ere isn't one (except that it's only open to US students - sorry. If anyone ha
# new contract that conformed with the open data mandate. If it were consistent
# If it were consistent with the Obama open data guidance, that RFP would requir
# ut of step with the administration’s open data policy.The founder of Hipcamp,
# is is a really important piece about open data and platforms.﻿ Work on sh-t th
# .﻿ An excellent demonstration of why Open Access lowers the barriers to knowle
# r is to fix the errors, not to blame open data for showing them, and give publ
# nd solution provider. The government open data movement is a big step in this
#  of Education on the design of their open data APIs, now is your chance. Detai
# e people figuring out how to use it. Open data platforms are a good way to get
# e it!﻿ My thoughts on free software, open source, and open data, in response t
# s on free software, open source, and open data, in response to Eric Raymond's
# etary DRM'd ebook format rather than open standards for the Kindle, I have alw
# at Park Day School in Oakland. Doors open at 10 a.m., close at 5 p.m.﻿ StreetC
# ia was Plan B." This talk - given to open government advocates - is particular
# Silicon Valley; private sector; +Jennifer Pahlka; interest rates;
# Common Core; idle resources; Bay Mini; East Bay; open data; New York;
# Maker Faire; Mini Maker; +Ezra Klein; Cabo Pulmo; Presidential
# Innovation; San Francisco; White House; on-demand economy,; granite
# workers; Well worth
# 0
#  reconstruction. 1
# 1 four 1
# 2 Does 1
# 3 Olympics 4
# 4 conjure 1
# 5 looking 9
# 6 Wikipedia...﻿ 1
# 7 turn-by-turn 1
# 8 basic, 1
# 9 advice. 1
# 10 advice, 3
# 11 befoul 1
# 12 research.What 1
# 13 data." 1
# 14 misunderstands 1
# 15 bringing 4
# 16 Maras.﻿ 1
# 17 Paul 1
# 18 straight 1
# 19 bill 1
# 20 (except 1
# 21 tired 1
# 22 second 2
# 23 empathyJake 1
# 24 intellect, 1
# 25 theory 1
# 26 errors 1
# 27 Unemployed 1
# 28 report, 1
# 29 Fear.(I 1
# 30 understood. 1
# 31 (Minute 1
# 32 kid, 1
# 33 Presidential 3
# 34 Neville 1
# 35 Apple's 1
# 36 here 8
# 37 iceberg. 1
# 38 fun 3
# 39 Zealanders, 1
# 40 borrowers 1
# 41 substance 2
# 42 Wikipedia. 1
# 43 reports 2
# 44 controversy 1
# 45 deniers. 1
# 46 Audi 1
# 47 golden 1
# 48 Three 1
# 49 brought 2
# 50 "The 6
# 51 obligation 1
# 52 oreilly.com. 1
# 53 spoke 2
# 54 Indeed, 3
# 55 music 1
# 56 until 5
# 57 Necessary 1
# 58 9, 1
# 59 successful 4
# 60 brings 4
# 61 show. 1
# 62 hurt 2
# 63 motorists.﻿ 1
# 64 away."Or 1
# 65 90 1
# 66 Nocera:“If 1
# 67 circumstances 1
# 68 on.fb.me/1fjCGYs﻿ 1
# 69 laughter, 1
# 70 example 7
# 71 catch. 1
# 72 La 1
# 73 organized 1
# 74 currency 1
# 75 want 19
# 76 minimum. 1
# 77 absolute 1
# 78 around. 1
# 79 LA 1
# 80 complaining 1
# 81 travel 4
# 82 damage 1
# 83 how 74
# 84 hot 1
# 85 A 15
# 86 Cooperative 1
# 87 beauty 1
# 88 Fussell 1
# 89 wrong 4
# 90 colorfully 2
# 91 effective 4
# 92 baggage 1
# 93 Fabulous 1
# 94 Another 1
# 95 keeps 1
# 96 tantalizing 1
# 97 democratic 2
# 98 blind 2
# 99 feedback 1
# 100 dreamed 1
# 101 vary 1
# 102 grandparents, 1
# 103 today. 1
# 104 IFTTT. 1
# 105 Washington.Bringing 1
# 106 fit 2
# 107 died, 1
# 108 fix 3
# 109 Othermachines 1
# 110 hidden 1
# 111 closed, 1
# 112 easier 1
# 113 hawthorn 1
# 114 enrich 2
# 115 Aurelia, 1
# 116 schools 2
# 117 yourself 2
# 118 undeveloped 1
# 119 represents 1
# 120 "punch 1
# 121 API 3
# 122 employers. 1
# 123 debug 1
# 124 mature. 1
# 125 financial 3
# 126 series 5
# 127 Datakind, 1
# 128 laboratory 1
# 129 self, 1
# 130 Nash)“…web 1
# 131 encourage 3
# 132 for-profit 2
# 133 Super 1
# 134 "Overwork 1
# 135 Work 2
# 136 resources.From 1
# 137 flourishes, 1
# 138 sheet 1
# 139 enormous 1
# 140 piecemeal 1
# 141 centers, 1
# 142 front, 1
# 143 naturalism 1
# 144 today's 4
# 145 reserving 1
# 146 shutdown, 1
# 147 state-run 1
# 148 Please 2
# 149 governments) 1
# 150 business.3. 1
# 151 me! 3
# 152 clarity 1
# 153 170 2
# 154 Bahamas, 1
# 155 basketball 1
# 156 service 3
# 157 needed 7
# 158 master 2
# 159 listed 1
# 160 folks. 1
# 161 sure, 3
# 162 rewards 1
# 163 “Goenkale,” 1
# 164 wisdom 1
# 165 Nietzche 1
# 166 Summit 5
# 167 Beautiful 2
# 168 Code 10
# 169 blossom. 2
# 170 Jaron 2
# 171 nations 1
# 172 RFPs, 1
# 173 idle 11
# 174 lawsuit, 1
# 175 vision, 1
# 176 feeling 3
# 177 old, 1
# 178 expect:﻿ 1
# 179 seduced 1
# 180 unintended 1
# 181 valuation.﻿ 1
# 182 heads, 1
# 183 well, 2
# 184 well. 2
# 185 Then 4
# 186 What? 1
# 187 aboard, 1
# 188 They 17
# 189 Myrow 1
# 190 Ask 1
# 191 What, 1
# 192 taxation 1
# 193 Angel, 1
# 194 love,—They 1
# 195 Levy's 1
# 196 object 1
# 197 simplify 1
# 198 letter 1
# 199 long, 1
# 200 resonated 1
# 201 long! 1
# 202 policies. 2
# 203 Typical 1
# 204 Shirky 2
# 205 episode 1
# 206 tech 11
# 207 sustainability.﻿ 1
# 208 detriment 1
# 209 came 8
# 210 behind!﻿ 1
# 211 saying 2
# 212 Union 1
# 213 meetings 1
# 214 Agency 2
# 215 terror. 1
# 216 Churchill, 1
# 217 lessons 5
# 218 theme 1
# 219 touched 2
# 220 rich 1
# 221 resources. 2
# 222 Account 1
# 223 Fascinating 3
# 224 men. 1
# 225 them. 3
# 226 sanctioning 1
# 227 them, 5
# 228 men! 1
# 229 lesson, 1
# 230 respond 3
# 231 fair 1
# 232 result 1
# 233 Android 2
# 234 resigned 1
# 235 best 22
# 236 shows:"...A 1
# 237 devices...﻿ 1
# 238 projects. 4
# 239 projects, 2
# 240 lots 2
# 241 Rise 2
# 242 Franco's 2
# 243 Cover. 1
# 244 preserve 1
# 245 letting 1
# 246 men 1
# 247 involved, 1
# 248 nature 2
# 249 rolled 1
# 250 self-congratulatory 1
# 251 extent 1
# 252 carbon 1
# 253 debt 3
# 254 live.﻿ 1
# 255 Theory 1
# 256 described, 1
# 257 cases—all 1
# 258 few—in 1
# 259 reported 1
# 260 Ahna 2
# 261 country 4
# 262 'Just 1
# 263 ambition. 1
# 264 argue 3
# 265 asked 7
# 266 directly, 2
# 267 nay, 1
# 268 money, 2
# 269 heroes."Children 1
# 270 profitable. 1
# 271 Sitting 1
# 272 . 1
# 273 bothers 1
# 274 extraction 1
# 275 much 22
# 276 privilege 2
# 277 superhuman 1
# 278 doldrums 1
# 279 life 7
# 280 wish 5
# 281 Consensus 1
# 282 kids 6
# 283 child 3
# 284 worked 6
# 285 spin 1
# 286 participatory 1
# 287 employ 1
# 288 played 2
# 289 Apple, 1
# 290 consent. 1
# 291 characterize 1
# 292 editorializing.via 1
# 293 Capital 2
# 294 said, 3
# 295 said. 1
# 296 hone 1
# 297 things 12
# 298 (https://medium.com/the-wtf-economy/the-wtf-economy-a3bd5f52ef00) 1
# 299 split 1
# 300 statistics:"Typically, 1
# 301 preaching. 1
# 302 principals 1
# 303 fairly 1
# 304 latter-day 1
# 305 Maybe 1
# 306 Rune 1
# 307 Customs, 1
# 308 echoed 1
# 309 which. 1
# 310 Fahlgren, 1
# 311 thing. 1
# 312 thing, 2
# 313 misrepresents 1
# 314 corporate 1
# 315 plaque 1
# 316 opinions 1
# 317 self.”'and"Kids 1
# 318 Hesiod, 1
# 319 #LeanInTogether﻿ 1
# 320 DRM 1
# 321 previous 2
# 322 Russians 3
# 323 equipment 1
# 324 taxes. 1
# 325 ease 1
# 326 had 34
# 327 DRM. 1
# 328 Surely 1
# 329 beloved 1
# 330 complex, 1
# 331 has 46
# 332 +Mikey 2
# 333 mantel, 1
# 334 Setup 1
# 335 possible 3
# 336 Yalom: 1
# 337 sleep, 1
# 338 poses 1
# 339 opinion. 4
# 340 occurring 1
# 341 Miracles 1
# 342 articulated 1
# 343 consequences."Shame 1
# 344 collection! 1
# 345 collection. 1
# 346 imagine.﻿ 1
# 347 remind 2
# 348 steps 1
# 349 Steven 4
# 350 Evidently, 1
# 351 Light." 1
# 352 Warren 1
# 353 right 11
# 354 old 8
# 355 crowd 3
# 356 people 41
# 357 System 2
# 358 Application 1
# 359 Whatever 1
# 360 Cohn's 2
# 361 for 231
# 362 bottom 1
# 363 creative 1
# 364 exposition 1
# 365 http://www.amazon.com/Sapiens-Humankind-Yuval-Noah-Harari/dp/0062316095/ref=asap_bc?ie=UTF8﻿ 1
# 366 citizen. 1
# 367 Instant 1
# 368 Poles).It 1
# 369 forever. 1
# 370 risks. 1
# 371 losing 1
# 372 KidsI 1
# 373 Think 1
# 374 dollars 3
# 375 citizens 2
# 376 "Surely 1
# 377 Brits, 1
# 378 “How 1
# 379 WHO 1
# 380 son 1
# 381 Management 2
# 382 +vivek 1
# 383 reducing 1
# 384 support 2
# 385 constantly 2
# 386 systems, 1
# 387 halls 1
# 388 happy 1
# 389 emotions: 1
# 390 “This 1
# 391 offer 4
# 392 so, 2
# 393 so. 1
# 394 Belgium, 1
# 395 healthcare.gov: 1
# 396 ignorance. 1
# 397 inside 6
# 398 devices 1
# 399 County 1
# 400 'That 1
# 401 lays 1
# 402 lives.via 1
# 403 wait, 1
# 404 Constitution, 1
# 405 proud 2
# 406 liberal 1
# 407 Personal 1
# 408 Humans 2
# 409 hall.﻿ 1
# 410 model, 1
# 411 Francisco 3
# 412 vanished: 1
# 413 floor 2
# 414 Mayo 1
# 415 direction:"When 1
# 416 role 9
# 417 developers 1
# 418 models 2
# 419 workers, 1
# 420 microbes 2
# 421 quandary 1
# 422 time 28
# 423 good: 1
# 424 significantly."It 1
# 425 below.﻿ 2
# 426 Barre, 1
# 427 here.﻿ 1
# 428 choice 2
# 429 gloomy 1
# 430 stays 3
# 431 minute 3
# 432 difference.﻿ 2
# 433 poor, 2
# 434 poor. 2
# 435 About 1
# 436 subway 1
# 437 team 9
# 438 Tam 1
# 439 Kevin 2
# 440 prevent 1
# 441 Kickstarter. 1
# 442 sign 3
# 443 change."This 1
# 444 https://plus.google.com/events/c7lf0pdvsn6nb0qj3cibnu6othc 1
# 445 current 7
# 446 falling 1
# 447 Francis 1
# 448 boost 1
# 449 illegally 1
# 450 funeral 1
# 451 understanding 4
# 452 address 1
# 453 alone 2
# 454 thinker. 1
# 455 along 3
# 456 My 13
# 457 Webb 2
# 458 brilliant 4
# 459 funded 1
# 460 accomplished 1
# 461 30, 1
# 462 Prize-winning 1
# 463 love 28
# 464 prefer 1
# 465 Abbey 1
# 466 specified 1
# 467 (heck, 1
# 468 Escaping 1
# 469 working 12
# 470 positive 1
# 471 predictions 1
# 472 tightly 1
# 473 by 106
# 474 work.” 1
# 475 wood 2
# 476 opposed 2
# 477 Pay, 1
# 478 loving 1
# 479 task, 1
# 480 mix.I 1
# 481 Pope 2
# 482 values 1
# 483 believed 1
# 484 Our 2
# 485 CampToday 1
# 486 Federal 5
# 487 awesome 1
# 488 educational 2
# 489 unveiled 1
# 490 allowed 3
# 491 kindness. 1
# 492 monitoring 1
# 493 definition, 1
# 494 savor 1
# 495 underneath, 1
# 496 Who 2
# 497 recreation.gov 1
# 498 optimal 2
# 499 Why 5
# 500 know.P.S. 1
# 501 (http://radar.oreilly.com/2012/07/open-source-small-business-report.html).Contrast 1
# 502 spot 1
# 503 applications 3
# 504 sure!BTW, 1
# 505 outcome"Real-time 1
# 506 improving 2
# 507 such 10
# 508 data 37
# 509 natural 1
# 510 so 49
# 511 funny:﻿ 1
# 512 below. 4
# 513 record, 2
# 514 years 5
# 515 hiring 2
# 516 experiments 1
# 517 society.I 1
# 518 user-centered, 1
# 519 tendency 2
# 520 disconnect 1
# 521 did, 1
# 522 troubles 1
# 523 globalization 1
# 524 Ryan's 1
# 525 spring."﻿ 1
# 526 readers, 1
# 527 year: 1
# 528 smarter 1
# 529 experiment, 1
# 530 experiment. 1
# 531 year, 2
# 532 year. 2
# 533 before."Fascinating!﻿ 1
# 534 experiment: 1
# 535 chores. 1
# 536 publishers. 1
# 537 repaired 1
# 538 riposted 1
# 539 Faire​ 1
# 540 poem, 2
# 541 crushing 1
# 542 breakthrough 1
# 543 Live 1
# 544 .need 1
# 545 small, 2
# 546 small. 1
# 547 protections 1
# 548 Joe 1
# 549 internet 7
# 550 people’s 1
# 551 million 6
# 552 incentives 1
# 553 quite 3
# 554 bills. 1
# 555 complicated 2
# 556 growth. 3
# 557 poems 1
# 558 +Paul 1
# 559 training 1
# 560 iterative 1
# 561 specifications, 1
# 562 massive 1
# 563 neglect 1
# 564 emotion 2
# 565 spoken 1
# 566 “they 1
# 567 one 47
# 568 generosity. 1
# 569 @OReillyMedia 3
# 570 vote 2
# 571 open 16
# 572 city 6
# 573 financing. 1
# 574 Monday 1
# 575 this:"He 1
# 576 2 1
# 577 draft 2
# 578 bits 1
# 579 on. 2
# 580 on, 2
# 581 today’s 1
# 582 bit, 1
# 583 depressed 5
# 584 distill 1
# 585 Piketty 1
# 586 future 15
# 587 bit: 1
# 588 buries 1
# 589 turned 3
# 590 Submit 1
# 591 sad 1
# 592 say 8
# 593 buried 1
# 594 Dalzell 1
# 595 saw 2
# 596 note 2
# 597 unlearn 1
# 598 Important 2
# 599 take 11
# 600 supply 2
# 601 wanting 2
# 602 time." 1
# 603 printer 1
# 604 Getting 1
# 605 knew 3
# 606 afternoon, 1
# 607 remarks 1
# 608 pages 1
# 609 something? 1
# 610 Schaaf 3
# 611 anything, 1
# 612 drive 1
# 613 federal 3
# 614 RFP.Comments 1
# 615 not. 1
# 616 CGI, 1
# 617 merit 1
# 618 myself.They 1
# 619 fecal 1
# 620 scarce 1
# 621 aggressive 2
# 622 urgings 1
# 623 Sacramento 1
# 624 outside 6
# 625 liberation 1
# 626 tears 2
# 627 going 16
# 628 hockey 2
# 629 wilfully 1
# 630 dispute 1
# 631 Applied 1
# 632 darkness. 1
# 633 usual. 1
# 634 digitize 1
# 635 between 12
# 636 procurement. 1
# 637 factories, 1
# 638 Magazine 1
# 639 prime 1
# 640 Cohn 1
# 641 borrow 1
# 642 worried 3
# 643 Barre's 1
# 644 priest 1
# 645 where 13
# 646 vision 2
# 647 neighbors. 1
# 648 cheat,' 1
# 649 job. 1
# 650 surgery 1
# 651 purest 1
# 652 That 8
# 653 ostensibly 1
# 654 sites 1
# 655 Healthcare.govDraw 1
# 656 exploration 2
# 657 jobs 4
# 658 "user 1
# 659 screen 2
# 660 His 3
# 661 awards 1
# 662 #Ebola 1
# 663 @HomeDepot 1
# 664 Nupedia, 2
# 665 enjoy. 1
# 666 Surveillance, 1
# 667 many 26
# 668 moon. 1
# 669 Spider 1
# 670 site. 2
# 671 site, 1
# 672 MayDay 1
# 673 expression 1
# 674 can't 1
# 675 allowance 1
# 676 yearly 1
# 677 hollowing 1
# 678 reading. 2
# 679 Ireland.Incidentally, 1
# 680 caring 2
# 681 @codeforamerica 3
# 682 winemaker, 1
# 683 breath 1
# 684 don’t 12
# 685 headquarters!﻿ 1
# 686 wants 5
# 687 thousand 1
# 688 photos 1
# 689 "gamification" 1
# 690 hashtag 2
# 691 former 2
# 692 single 4
# 693 policies 4
# 694 situation 1
# 695 Marshall-Green 1
# 696 engaged 2
# 697 contract 2
# 698 technology 15
# 699 management. 1
# 700 rooting 1
# 701 surveillance 3
# 702 (sentences 1
# 703 livestream, 1
# 704 I 229
# 705 2002. 1
# 706 internet, 2
# 707 Eisen 1
# 708 Tulsa!﻿ 1
# 709 reporting. 1
# 710 Own 1
# 711 teacher.What 1
# 712 outcome?"(http://beyondtransparency.org/chapters/part-5/open-data-and-algorithmic-regulation/).﻿ 1
# 713 costs 2
# 714 scholarship 1
# 715 summer 1
# 716 http://oreil.ly/1mFJJgw 1
# 717 being 11
# 718 officers, 1
# 719 rest 3
# 720 (a 2
# 721 city-owned 1
# 722 Zach 2
# 723 skied 1
# 724 Advice 1
# 725 (I 2
# 726 Market. 1
# 727 around 10
# 728 process, 2
# 729 Sachs 1
# 730 dark 1
# 731 Aunt 1
# 732 sorry. 1
# 733 #FutureCrimesConvo, 1
# 734 world 14
# 735 satisfaction 1
# 736 government?" 1
# 737 (utilising 2
# 738 Mal 1
# 739 travelogue 2
# 740 Backchannel 1
# 741 Instead, 4
# 742 +Allen 1
# 743 museums, 1
# 744 superintendent 1
# 745 couldn't 1
# 746 Uber. 1
# 747 Brandon 2
# 748 "adversary." 1
# 749 thinks 2
# 750 Rube 1
# 751 scholarships 1
# 752 Shame 2
# 753 noon 1
# 754 Projects 1
# 755 think. 1
# 756 smoothly.A 1
# 757 scientific 1
# 758 power 3
# 759 think) 1
# 760 leadership 1
# 761 Alfie 2
# 762 reversing 1
# 763 Empire. 1
# 764 stone 5
# 765 Inspire 1
# 766 package 1
# 767 industry 2
# 768 favorite 4
# 769 side 1
# 770 applications, 1
# 771 act 2
# 772 wikis 1
# 773 No 2
# 774 parties 2
# 775 accumulated 1
# 776 her 12
# 777 "high 1
# 778 NY 4
# 779 obvious, 1
# 780 obvious. 1
# 781 recommends 1
# 782 complete 2
# 783 services, 2
# 784 headset, 1
# 785 another, 1
# 786 with 137
# 787 buying 4
# 788 handsome 1
# 789 pull 1
# 790 underwater. 1
# 791 House 3
# 792 site 5
# 793 opens:"Something’s 1
# 794 agree 7
# 795 touchstone 1
# 796 regimes 1
# 797 detailed 1
# 798 gone 2
# 799 sneaky, 1
# 800 certain 3
# 801 forgot 1
# 802 am 17
# 803 an 83
# 804 How 8
# 805 as 111
# 806 at 109
# 807 formulation 1
# 808 watched 2
# 809 allocator 1
# 810 managing 1
# 811 Read 2
# 812 Atlantic 1
# 813 2007 1
# 814 Kurdish 1
# 815 training.﻿ 1
# 816 vocabulary 1
# 817 annex 1
# 818 walk. 1
# 819 planners 1
# 820 CrownedWith 1
# 821 form.'"To 1
# 822 city's 2
# 823 Hardware 2
# 824 fraudulent 1
# 825 Street 2
# 826 mass 1
# 827 Cove.Around 1
# 828 behavioral 4
# 829 "Bro" 1
# 830 original 1
# 831 9/11 1
# 832 consider 1
# 833 robots, 1
# 834 welfare 1
# 835 PAC, 1
# 836 causes 2
# 837 it.5. 1
# 838 hunting 2
# 839 illustrates 1
# 840 Crimes, 1
# 841 WAR 1
# 842 Shiller's 1
# 843 to 681
# 844 Hedlund 1
# 845 norm 1
# 846 +Steven 1
# 847 debit 1
# 848 corporations, 1
# 849 illustrated 1
# 850 quasi-governmental 1
# 851 Noah 1
# 852 officials. 1
# 853 joined 2
# 854 +William 1
# 855 large 3
# 856 adjust 3
# 857 facsimile 1
# 858 small 11
# 859 unfolds.﻿ 1
# 2497 learned 9
# 2498 overrule 1
# 2499 Fellows. 1
# 2500 ETL, 1
# 2501 @pahlkadot 2
# 2502 answers 1
# 2503 time!﻿ 1
# 2504 strong 1
# 2505 reality. 1
# 2506 ahead 1
# 2507 inspired 1
# 2508 anthology, 1
# 2509 audiobook 1
# 2510 emotion, 1
# 2511 amount 3
# 2512 backstage. 1
# 2513 advertising 2
# 2514 Olympics.” 1
# 2515 BillGuard 1
# 2516 uniquely 1
# 2517 family 4
# 2518 partnering 1
# 2519 requiring 1
# 2520 ask 2
# 2521 Next:Economy, 1
# 2522 S. 1
# 2523 story, 1
# 2524 +Clay 2
# 2525 conventional 1
# 2526 Days: 1
# 2527 takes 3
# 2528 condition."Lovely.And 1
# 2529 taken 2
# 2530 lowering 1
# 2531 Faire 4
# 2532 St 1
# 2533 @WhiteHouse. 1
# 2534 So 14
# 2535 Seamus 1
# 2536 Freudian 1
# 2537 nine 1
# 2538 take. 1
# 2539 SF 1
# 2540 history 5
# 2541 IBM 1
# 2542 phrase 1
# 2543 lacks 1
# 2544 bread. 1
# 2545 bank, 1
# 2546 craft. 1
# 2547 bug. 1
# 2548 Labs, 1
# 2549 Bezos. 1
# 2550 tried 3
# 2551 Reciprocal 1
# 2552 derived 1
# 2553 tries 1
# 2554 goals. 1
# 2555 Syria 2
# 2556 apt, 1
# 2557 a 502
# 2558 criticize 1
# 2559 though, 2
# 2560 banks 2
# 2561 justice. 1
# 2562 help 20
# 2563 soon 1
# 2564 SF, 1
# 2565 Atlas 1
# 2566 MIT 1
# 2567 case. 1
# 2568 taxpayer 1
# 2569 botched 1
# 2570 actually 8
# 2571 Internalizing 1
# 2572 systems 4
# 2573 founders 2
# 2574 Pacific, 1
# 2575 haven't 1
# 2576 #IoTH, 1
# 2577 food 1
# 2578 stone-lifting 1
# 2579 you've 5
# 2580 ff) 1
# 2581 $75,000 1
# 2582 Tap 1
# 2583 system" 1
# 2584 fully 1
# 2585 system, 1
# 2586 intervene 1
# 2587 +Jim 2
# 2588 fairy 1
# 2589 SAVE 1
# 2590 isn't 6
# 2591 referred 1
# 2592 speakerphone, 1
# 2593 math. 1
# 2594 www.futurecrimes.com﻿ 1
# 2595 house, 1
# 2596 energy, 2
# 2597 periodically. 1
# 2598 Washington, 1
# 2599 beyond 5
# 2600 event 10
# 2601 leave 1
# 2602 since 4
# 2603 safety 1
# 2604 7 1
# 2605 issue 1
# 2606 None 1
# 2607 timeline 1
# 2608 dung 1
# 2609 According 1
# 2610 reason 2
# 2611 put 9
# 2612 Fidelity 1
# 2613 heroic 1
# 2614 Fantastic 1
# 2615 uprooted 1
# 2616 launch 2
# 2617 Boston 1
# 2618 terrible 4
# 2619 terribly 1
# 2620 interviews 1
# 2621 Indians, 1
# 2622 norm. 1
# 2623 conference﻿ 1
# 2624 Maps 1
# 2625 talked 2
# 2626 minutes, 2
# 2627 Economy." 1
# 2628 visions 1
# 2629 horse 1
# 2630 expensive, 1
# 2631 Nature 1
# 2632 (Chapter 2
# 2633 identity."I 1
# 6034 already, 1
# 6035 fiasco, 2
# 6036 might 6
# 6037 return 1
# 6038 Makers/Exhibitors/Performers, 1
# 6039 framework 1
# 6040 party 3
# 6041 communities 1
# 6042 bigger 3
# 6043 Sunday's 1
# 6044 inequality 2
# 6045 works."The 1
# 6046 generation 1
# 6047 everyone"Adjustments 1
# 6048 Complex 1
# 6049 Punished 1
# 6050 Passport 1
# 6051 More 2
# 6052 Boston, 1
# 6053 Samuel 1
# 6054 health 3
# 6055 oreil.ly/19paQnz﻿ 1
# 6056 Allspaw 1
# 6057 teach 4
# 6058 come: 1
# 6059 globalization, 1
# 6060 People 2
# 6061 providing, 1
# 6062 Lake, 1
# 6063 Expect 1
# 6064 properly. 1
# 6065 Elon 1
# 6066 marketplace. 2
# 6067 feed 2
# 6068 feel 7
# 6069 6. 1
# 6070 Indian 1
# 6071 recreation, 1
# 6072 story 10
# 6073 leading 2
# 6074 interact 1
# 6075 realityThe 1
# 6076 Larry 1
# 6077 passed 1
# 6078 store 1
# 6079 from. 2
# 6080 corporations 1
# 6081 "When 1
# 6082 $4 1
# 6083 $5 1
# 6084 kind 10
# 6085 nagging 1
# 6086 vial 1
# 6087 aims 1
# 6088 it.﻿ 1
# 6089 interview, 1
# 6090 risky 1
# 6091 modeled 1
# 6092 infrastructure, 1
# 6093 infrastructure. 1
# 6094 hour-long 1
# 6095 first. 1
# 6096 me.) 1
# 6097 finding 3
# 6098 added 1
# 6099 purpose.I 1
# 6100 friends), 1
# 6101 wasn’t 3
# 6102 toldthe 1
# 6103 nothing 5
# 6104 achievement 1
# 6105 bugaboo 1
# 6106 paintings, 1
# 6107 skyline.But 1
# 6108 traditional 2
# 6109 daily. 1
# 6110 night, 3
# 6111 lying 1
# 6112 differentiate 1
# 6113 stones 2
# 6114 JP 1
# 6115 Gilead 1
# 6116 2012, 1
# 6117 meditation, 1
# 6118 Morgan, 1
# 6119 MILLION 1
# 6120 grotesque 1
# 6121 NEXT 1
# 6122 child-raising 1
# 6123 his 58
# 6124 hit 1
# 6125 story.McEvers: 1
# 6126 Both 2
# 6127 Yorkshire 1
# 6128 him 17
# 6129 one.﻿ 1
# 6130 Bluetooth 2
# 6131 school.﻿ 1
# 6132 investigate 1
# 6133 activity 1
# 6134 sustainable 2
# 6135 needle."Very 1
# 6136 Networks 1
# 6137 wrote 10
# 6138 Chairman 1
# 6139 art 1
# 6140 city, 1
# 6141 achieved 2
# 6142 defense 2
# 6143 are 123
# 6144 laurel 1
# 6145 learns 1
# 6146 implementation." 1
# 6147 nailed 1
# 6148 Music:"I 1
# 6149 libraries 1
# 6150 various 4
# 6151 Gonzalez!﻿ 1
# 6152 after. 1
# 6153 Things. 1
# 6154 creating 2
# 6155 grappling 1
# 6156 sold 1
# 6157 attention 2
# 6158 achieve, 1
# 6159 days. 1
# 6160 days, 2
# 6161 Google's 1
# 6162 file.)Caller: 1
# 6163 competent 1
# 6164 self-esteem, 1
# 6165 excellence, 1
# 6166 AND 2
# 6167 watchword, 1
# 6168 became 1
# 6169 Esko 1
# 6571 Area, 1
# 6572 1,700th 1
# 6573 brain 1
# 6574 thrive 1
# 6575 view 5
# 6576 knowing 1
# 6577 modulo 1
# 6578 YouTube.com/DIYTV 1
# 6579 acquired 1
# 6580 players.There 1
# 6581 publisher. 1
# 6582 bakeries, 1
# 6583 ground, 1
# 6584 (The 4
# 6585 Britain 1
# 6586 superb 1
# 6587 premises 1
# 6588 DRNK 1
# 6589 stories 5
# 6590 command, 1
# 6591 acquire, 1
# 6592 publishers 1
# 6593 ability 5
# 6594 joy 1
# 6595 agencies 1
# 6596 amenities, 1
# 6597 ideas, 3
# 6598 Human 1
# 6599 submarine!" 1
# 6600 Unfortunately, 1
# 6601 Jascha 1
# 6602 Cohn, 1
# 6603 walk 3
# 6604 he’s 1
# 6605 butcher, 1
# 6606 connection.﻿ 1
# 6607 Discount 1
# 6608 rich. 1
# 6609 possible.I 1
# 6610 Guild 1
# 6611 sufficient 1
# 6612 Credit 2
# 6613 improved 1
# 6614 present 2
# 6615 choices 1
# 6616 will 53
# 6617 respond, 1
# 6618 chart, 1
# 6619 Potentially 1
# 6620 rename 1
# 6621 ringing 1
# 6622 Quidsi, 1
# 6623 selfishly, 1
# 6624 fan. 1
# 6625 Hope 1
# 6626 fails, 1
# 6627 perhaps 1
# 6628 member 1
# 6629 units 2
# 6630 gets 5
# 6631 difficult 1
# 6632 this.BTW, 1
# 6633 succulent 1
# 6634 Todd 1
# 6635 automation 1
# 6636 student 3
# 6637 'Best 1
# 6638 correspondent 1
# 6639 Muir 1
# 6640 (although 1
# 6641 States 2
# 6642 failures 2
# 6643 Moral 1
# 6644 MEMORY 1
# 6645 Never 1
# 6646 routinely 2
# 6647 heavily 2
# 6648 only, 1
# 6649 influencers 1
# 6650 old-school 1
# 6651 biologist 2
# 6652 happiness 1
# 6653 Matt 1
# 6654 fund!﻿ 1
# 6655 guts 1
# 6656 arresting 1
# 6657 other 31
# 6658 ski 1
# 6659 acted 2
# 6660 soon...﻿ 1
# 6661 week:RT 1
# 6662 who's 1
# 6663 they’ve 1
# 6664 know 24
# 6665 press 4
# 6666 redesign 1
# 6667 chutzpah 1
# 6668 who'd 1
# 6669 That’s 1
# 6670 death."And 1
# 6671 handicapping 1
# 6672 helpful 4
# 6673 taxpayers 1
# 6674 Konnikova's 1
# 6675 Heaney's 2
# 6676 yours. 1
# 6677 because 20
# 6678 scared 1
# 6679 searching 1
# 6680 platforms 1
# 6681 growth 5
# 6682 110 1
# 6683 Jonathan 1
# 6684 neglecting 1
# 6685 fun. 1
# 6686 lead 1
# 6687 lean 1
# 6688 sake, 1
# 6689 backups. 1
# 6690 Catalog 1
# 6691 Regulations?Evgeny 1
# 6692 platform, 2
# 6693 capture", 1
# 6694 wouldn’t 1
# 6695 Brokeback 1
# 6696 awards. 1
# 6697 rare 1
# 6698 getting 10
# 6699 "Amazon.love 1
# 6700 urged 1
# 6701 surge 1
# 6702 Americans 3
# 6703 “RUS-SI-YA”, 1
# 6704 mine) 1
# 6705 Really 2
# 6706 own 13
# 6707 polished 1
# 6708 models.The 1
# 6709 promise 3
# 6710 forget 5
# 6711 Lanier's 3
# 6712 126,000. 1
# 6713 Bruner 1
# 6714 funds 1
# 6715 that.﻿ 2
# 6716 (Part 1
# 6717 Consumer 1
# 6718 made 9
# 6719 tactics 1
# 6720 whether 10
# 6721 Michener)quoteinvestigator.com/2010/08/27/master/Thanks 1
# 6722 distract 1
# 6723 this. 2
# 6724 below 1
# 6725 demonstrate 1
# 6726 Critic." 1
# 6727 inadequate 1
# 6728 inept. 1
# 6729 Vancouver 2
# 6730 goodness 1
# 6731 (preferably 1
# 6732 Geometric 1
# 6733 kind, 1
# 6734 percent 3
# 6735 book 14
# 6736 toured 1
# 6737 long-time 1
# 6738 incredibly 3
# 6739 conclusion 1
# 6740 junk 1
# 6741 kinds 6
# 6742 volumes 1
# 6743 inherently 1
# 6744 Future 5
# 6745 Greene's 2
# 6746 HONY's 1
# 6747 ranks 1
# 6748 function, 1
# 6749 percent? 1
# 6750 "Government 1

# %% [markdown]
# # Example 9.用TF-IDF来查询Google+数据

# %%
import json
import nltk

# Load in human language data from wherever you've saved it

DATA = 'resources/ch04-googleplus/107033731246200681024.json'
data = json.loads(open(DATA).read())
# XXX: Provide your own query terms here
QUERY_TERMS = ['SOPA']

activities = [activity['object']['content'].lower().split() for activity in data if activity['object']['content'] != ""]

# TextCollection provides tf, idf, and tf_idf abstractions so 
# that we don't have to maintain/compute them ourselves
tc = nltk.TextCollection(activities)
relevant_activities = []
for idx in range(len(activities)):
    score = 0
    for term in [t.lower() for t in QUERY_TERMS]:
        score += tc.tf_idf(term, activities[idx])
    if score > 0:
        relevant_activities.append({'score': score, 'title': data[idx]['title'],  'url': data[idx]['url']})

# Sort by score and display results

relevant_activities = sorted(relevant_activities,  key=lambda p: p['score'], reverse=True)
for activity in relevant_activities:
    print activity['title']
    print '\tLink: %s' % (activity['url'], )
    print '\tScore: %s' % (activity['score'], )
    print

# %% [markdown]
# # Example 10. 使用余弦相似度找到相似的文档

# %%
import json
import nltk

# Load in human language data from wherever you've saved it
DATA = 'resources/ch04-googleplus/107033731246200681024.json'
data = json.loads(open(DATA).read())
# Only consider content that's ~1000+ words.
data = [ post for post in data if len(post['object']['content']) > 1000 ]

all_posts = [post['object']['content'].lower().split()  for post in data ]


# Provides tf, idf, and tf_idf abstractions for scoring

tc = nltk.TextCollection(all_posts)

# Compute a term-document matrix such that td_matrix[doc_title][term]
# returns a tf-idf score for the term in the document

td_matrix = {}
for idx in range(len(all_posts)):
    post = all_posts[idx]
    fdist = nltk.FreqDist(post)

    doc_title = data[idx]['title']
    url = data[idx]['url']
    td_matrix[(doc_title, url)] = {}

    for term in fdist.iterkeys():
        td_matrix[(doc_title, url)][term] = tc.tf_idf(term, post)
        
# Build vectors such that term scores are in the same positions...

distances = {}
for (title1, url1) in td_matrix.keys():

    distances[(title1, url1)] = {}
    (min_dist, most_similar) = (1.0, ('', ''))

    for (title2, url2) in td_matrix.keys():

        # Take care not to mutate the original data structures
        # since we're in a loop and need the originals multiple times

        terms1 = td_matrix[(title1, url1)].copy()
        terms2 = td_matrix[(title2, url2)].copy()

        # Fill in "gaps" in each map so vectors of the same length can be computed

        for term1 in terms1:
            if term1 not in terms2:
                terms2[term1] = 0

        for term2 in terms2:
            if term2 not in terms1:
                terms1[term2] = 0

        # Create vectors from term maps

        v1 = [score for (term, score) in sorted(terms1.items())]
        v2 = [score for (term, score) in sorted(terms2.items())]

        # Compute similarity amongst documents

        distances[(title1, url1)][(title2, url2)] = \
            nltk.cluster.util.cosine_distance(v1, v2)

        if url1 == url2:
            #print distances[(title1, url1)][(title2, url2)]
            continue

        if distances[(title1, url1)][(title2, url2)] < min_dist:
            (min_dist, most_similar) = (distances[(title1, url1)][(title2, url2)], (title2, url2))
    
    print '''Most similar to %s (%s) %s (%s) score %f ''' % (title1, url1, most_similar[0], most_similar[1], 1-min_dist)
# Out:
# Most similar to Absolutely fascinating exploration of the microbiome of a city.
#
# For those who don't know what the microbiome... (https://plus.google.com/+TimOReilly/posts/7EaHeYc1BiB) I read Brad Stone's history of Amazon, The Everything Store,  over the holidays, and recommend it highly... (https://plus.google.com/+TimOReilly/posts/aeo8XvLdxA4) score 0.046418
# Most similar to If we are going to transform government, we need both an inside game and an outside game.
#
# The inside... (https://plus.google.com/+TimOReilly/posts/WySK63oPskZ) "We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm) score 0.067634
# Most similar to Can We Use Data to Make Better Regulations?
#
# Evgeny Morozov either misunderstands or misrepresents the... (https://plus.google.com/+TimOReilly/posts/gboAUahQwuZ) "Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ... (https://plus.google.com/+TimOReilly/posts/1Lcxb3b8VPH) score 0.096167
# Most similar to The Myth of the Spoiled Child
#
# There is an interesting op-ed in the NY Times by Alfie Cohn, who has ... (https://plus.google.com/+TimOReilly/posts/c1f9KVXsivD) How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C) score 0.108148
# Most similar to Amazing story about digital transformation http://www.codeforamerica.org/blog/2015/11/30/a-new-approach... (https://plus.google.com/+TimOReilly/posts/BRmKh2ycaPe) How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C) score 0.091677
# Most similar to Nassau, The Bahamas Airport Travel Advice
#
# If anyone happens to travel to Nassau, the Bahamas, I thought... (https://plus.google.com/+TimOReilly/posts/dpQDew7sPbu) Journalism vs. Punditry: NPR's Kelly McEvers on Why Reporting Matters
#
# There was a great segment on ... (https://plus.google.com/+TimOReilly/posts/NGZmQLE392X) score 0.055051
# Most similar to The 10-year contract for the US recreation.gov site  is up for renewal, and the Department of the Interior... (https://plus.google.com/+TimOReilly/posts/cmjFvKC5S9v) Great talk by Maciej Ceglowski.  Funny, smart, and with an important message.  Just like Maciej all ... (https://plus.google.com/+TimOReilly/posts/b17bWhGfkH3) score 0.061163
# Most similar to "We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm) I wrote a long piece on LinkedIn reflecting on Steven Brill's excellent Time Magazine cover story "Code... (https://plus.google.com/+TimOReilly/posts/i1zGyh4DWQq) score 0.158643
# Most similar to +Clay Shirky always has the most insightful and colorfully told take on the intersection of technology... (https://plus.google.com/+TimOReilly/posts/b3Am9orRSrX) I read Brad Stone's history of Amazon, The Everything Store,  over the holidays, and recommend it highly... (https://plus.google.com/+TimOReilly/posts/aeo8XvLdxA4) score 0.053260
# Most similar to "This was an Olympics by and for the Russians."
#
# From +Dale Dougherty's travelogue on the Sochi Olympics... (https://plus.google.com/+TimOReilly/posts/Yi4bcrdmCcG) "That's What I Came For"
#
# I loved +Dale Dougherty's insights into what makes him a sports fan, from ... (https://plus.google.com/+TimOReilly/posts/HJp6MQbo8U8) score 0.179031
# Most similar to Urban Office-steading in Brooklyn
#
# On Monday, I visited O'Reilly Media's small development office in... (https://plus.google.com/+TimOReilly/posts/JUPjG8whL9Y) "This was an Olympics by and for the Russians."
#
# From +Dale Dougherty's travelogue on the Sochi Olympics... (https://plus.google.com/+TimOReilly/posts/Yi4bcrdmCcG) score 0.043257
# Most similar to Journalism vs. Punditry: NPR's Kelly McEvers on Why Reporting Matters
#
# There was a great segment on ... (https://plus.google.com/+TimOReilly/posts/NGZmQLE392X) Great talk by Maciej Ceglowski.  Funny, smart, and with an important message.  Just like Maciej all ... (https://plus.google.com/+TimOReilly/posts/b17bWhGfkH3) score 0.079538
# Most similar to How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C) The Myth of the Spoiled Child
#
# There is an interesting op-ed in the NY Times by Alfie Cohn, who has ... (https://plus.google.com/+TimOReilly/posts/c1f9KVXsivD) score 0.108148
# Most similar to I love the praise for my niece Ahna O'Reilly in this review of James Franco's production of Faulkner's... (https://plus.google.com/+TimOReilly/posts/AL2qe62rmgq) Journalism vs. Punditry: NPR's Kelly McEvers on Why Reporting Matters
#
# There was a great segment on ... (https://plus.google.com/+TimOReilly/posts/NGZmQLE392X) score 0.053343
# Most similar to What a great piece by Eric Liu!  He talks about the efforts of various people to help him track down... (https://plus.google.com/+TimOReilly/posts/Z7xGVUtUM9M) I wrote a long piece on LinkedIn reflecting on Steven Brill's excellent Time Magazine cover story "Code... (https://plus.google.com/+TimOReilly/posts/i1zGyh4DWQq) score 0.040205
# Most similar to Great talk by Maciej Ceglowski.  Funny, smart, and with an important message.  Just like Maciej all ... (https://plus.google.com/+TimOReilly/posts/b17bWhGfkH3) Can We Use Data to Make Better Regulations?
#
# Evgeny Morozov either misunderstands or misrepresents the... (https://plus.google.com/+TimOReilly/posts/gboAUahQwuZ) score 0.086214
# Most similar to Why Common Core is Like Healthcare.gov
#
# Draw a bold line between this piece on the failure of the Common... (https://plus.google.com/+TimOReilly/posts/XebEgwjhV35) "We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm) score 0.087016
# Most similar to How fragile life is, even for the best of us. We heard this morning that our friend Jake Brewer was ... (https://plus.google.com/+TimOReilly/posts/jV8jeKeWWyf) Journalism vs. Punditry: NPR's Kelly McEvers on Why Reporting Matters
#
# There was a great segment on ... (https://plus.google.com/+TimOReilly/posts/NGZmQLE392X) score 0.051098
# Most similar to I wrote a long piece on LinkedIn reflecting on Steven Brill's excellent Time Magazine cover story "Code... (https://plus.google.com/+TimOReilly/posts/i1zGyh4DWQq) "We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm) score 0.158643
# Most similar to Why Government Investment Makes Sense Now
#
# I was interested to see what appears to be a Libertarian-... (https://plus.google.com/+TimOReilly/posts/DHV5kFPWdiP) If we are going to transform government, we need both an inside game and an outside game.
#
# The inside... (https://plus.google.com/+TimOReilly/posts/WySK63oPskZ) score 0.058899
# Most similar to My dear friend Carolyn Shapiro does amazing projects that help communities understand their history,... (https://plus.google.com/+TimOReilly/posts/F1E8rsm3URP) "We don't need new policies. We need better implementation."
#
# Last night, I hosted Oakland City Councilor... (https://plus.google.com/+TimOReilly/posts/M1kH7bErNDm) score 0.045352
# Most similar to This piece is utterly brilliant, an important manifesto on how the DIY movement is enabling a new era... (https://plus.google.com/+TimOReilly/posts/TPdN3j1jNw9) I am somewhat appalled by the sloppy thinking of many of the Internet's latter-day critics. For example... (https://plus.google.com/+TimOReilly/posts/F85gaWoBp3Z) score 0.056309
# Most similar to Google Teams Up with GM, Honda and Audi to Bring Android to Cars
#
# I'm intrigued but a bit skeptical ... (https://plus.google.com/+TimOReilly/posts/cNpJxzQhbp9) Great talk by Maciej Ceglowski.  Funny, smart, and with an important message.  Just like Maciej all ... (https://plus.google.com/+TimOReilly/posts/b17bWhGfkH3) score 0.062044
# Most similar to I am somewhat appalled by the sloppy thinking of many of the Internet's latter-day critics. For example... (https://plus.google.com/+TimOReilly/posts/F85gaWoBp3Z) I read Brad Stone's history of Amazon, The Everything Store,  over the holidays, and recommend it highly... (https://plus.google.com/+TimOReilly/posts/aeo8XvLdxA4) score 0.086719
# Most similar to "Surely Democrats and Republicans could agree to cut billions from a failed program like this!" you ... (https://plus.google.com/+TimOReilly/posts/1Lcxb3b8VPH) Can We Use Data to Make Better Regulations?
#
# Evgeny Morozov either misunderstands or misrepresents the... (https://plus.google.com/+TimOReilly/posts/gboAUahQwuZ) score 0.096167
# Most similar to "That's What I Came For"
#
# I loved +Dale Dougherty's insights into what makes him a sports fan, from ... (https://plus.google.com/+TimOReilly/posts/HJp6MQbo8U8) "This was an Olympics by and for the Russians."
#
# From +Dale Dougherty's travelogue on the Sochi Olympics... (https://plus.google.com/+TimOReilly/posts/Yi4bcrdmCcG) score 0.179031
# Most similar to  +Maria Konnikova's NY Times article about the role of time and attention scarcity in the cycle of poverty... (https://plus.google.com/+TimOReilly/posts/4qHJZJU6Dtb) The Myth of the Spoiled Child
#
# There is an interesting op-ed in the NY Times by Alfie Cohn, who has ... (https://plus.google.com/+TimOReilly/posts/c1f9KVXsivD) score 0.067566
# Most similar to Work on sh-t that matters, aka Poo Camp
#
# Today was the annual chicken coop poo cleanup. (The chickens... (https://plus.google.com/+TimOReilly/posts/3vTSVs6CcdY) I read Brad Stone's history of Amazon, The Everything Store,  over the holidays, and recommend it highly... (https://plus.google.com/+TimOReilly/posts/aeo8XvLdxA4) score 0.035957
# Most similar to The Guardian just published Nobel Prize-winning poet Seamus Heaney's last known poem, "In a Field", ... (https://plus.google.com/+TimOReilly/posts/gCKfRoa9WoP) How to Raise Moral Children
#
# I thought this article on child-raising had a lot of good ideas in it. ... (https://plus.google.com/+TimOReilly/posts/NVZVmG1ct6C) score 0.032238
# Most similar to This was my favorite piece in this Sunday's New York Times. It's a fascinating article about CBW, a ... (https://plus.google.com/+TimOReilly/posts/VsvsS9nagtU) If we are going to transform government, we need both an inside game and an outside game.
#
# The inside... (https://plus.google.com/+TimOReilly/posts/WySK63oPskZ) score 0.058035
# Most similar to I read Brad Stone's history of Amazon, The Everything Store,  over the holidays, and recommend it highly... (https://plus.google.com/+TimOReilly/posts/aeo8XvLdxA4) I am somewhat appalled by the sloppy thinking of many of the Internet's latter-day critics. For example... (https://plus.google.com/+TimOReilly/posts/F85gaWoBp3Z) score 0.086719
# Most similar to Who will build the “god platform” for the Internet of Things?
#
# The idea that everyone will have a separate... (https://plus.google.com/+TimOReilly/posts/fTnKQCQdikp) Google Teams Up with GM, Honda and Audi to Bring Android to Cars
#
# I'm intrigued but a bit skeptical ... (https://plus.google.com/+TimOReilly/posts/cNpJxzQhbp9) score 0.059267

# %% [markdown]
# # Code to create a matrix diagram displaying linkages between Google+ activities as illustrated in Figure 6.

# %%
import json
from operator import itemgetter
import nltk
from IPython.display import IFrame
from IPython.core.display import display

# Load in human language data from wherever you've saved it
DATA = 'resources/ch04-googleplus/107033731246200681024.json'
# Only consider content that's ~100+ words.
data = [post for post in json.loads(open(DATA).read())
        if len(post['object']['content']) > 1000]


all_posts = [post['object']['content'].lower().split()  for post in data]

# Provides tf, idf, tf_idf abstractions for scoring

tc = nltk.TextCollection(all_posts)

# Compute a term-document matrix such that td_matrix[doc_title][term]
# returns a tf-idf score for the term in the document

td_matrix = {}
for idx in range(len(all_posts)):
    post = all_posts[idx]
    fdist = nltk.FreqDist(post)

    doc_title = data[idx]['title']
    url = data[idx]['url']
    td_matrix[(doc_title, url)] = {}

    for term in fdist.iterkeys():
        td_matrix[(doc_title, url)][term] = tc.tf_idf(term, post)

# Build vectors such that term scores are in the same positions...

distances = {}

# Visualization output requires a list of nodes with values and a list of links that have
# source and destination targets. We'll pre-build the list of nodes here and create an index
# so that we can easily create links from titles after we compute the most similar items
# on each iteration of the outer loop

viz_links = []
viz_nodes = [ {'title' : title, 'url' : url} for (title, url) in td_matrix.keys() ]

foo = 0
for vn in viz_nodes:
    vn.update({'idx' : foo})
    foo += 1

idx = dict(zip([ vn['title'] for vn in viz_nodes ], range(len(viz_nodes))))


for (title1, url1) in td_matrix.keys():

    distances[(title1, url1)] = {}
    (min_dist, most_similar) = (1.0, ('', ''))

    for (title2, url2) in td_matrix.keys():

        # Take care not to mutate the original data structures
        # since we're in a loop and need the originals multiple times

        terms1 = td_matrix[(title1, url1)].copy()
        terms2 = td_matrix[(title2, url2)].copy()

        # Fill in "gaps" in each map so vectors of the same length can be computed

        for term1 in terms1:
            if term1 not in terms2:
                terms2[term1] = 0

        for term2 in terms2:
            if term2 not in terms1:
                terms1[term2] = 0

        # Create vectors from term maps

        v1 = [score for (term, score) in sorted(terms1.items())]
        v2 = [score for (term, score) in sorted(terms2.items())]

        # Compute similarity amongst documents

        distances[(title1, url1)][(title2, url2)] = \
            nltk.cluster.util.cosine_distance(v1, v2)

        if url1 == url2:
            #print distances[(title1, url1)][(title2, url2)]
            continue

        if distances[(title1, url1)][(title2, url2)] < min_dist:
            (min_dist, most_similar) = (distances[(title1, url1)][(title2,
                                         url2)], (title2, url2))
    
    viz_links.append({'source' : idx[title1], 'target' : idx[most_similar[0]], 'score' : 1 - min_dist})
    

f = open('resources/ch04-googleplus/viz/matrix.json', 'w')
f.write(json.dumps({'nodes' : viz_nodes, 'links' : viz_links}, indent=1))
f.close()

# Display the visualization below with an inline frame
display(IFrame('files/resources/ch04-googleplus/viz/matrix.html', '100%', '600px'))

# You could also serve it by running SimpleHTTPServer in the viz directory as follows:
# $ python -m SimpleHTTPServer 9000
# Now, open http://localhost:9000/matrix.html in your web browser
# Out:
#         <iframe
#             width="100%"
#             height=600px"
#             src="files/resources/ch04-googleplus/viz/matrix.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Example 11.对一个句子用NLTK来计算二元文法和搭配

# %%
import nltk

sentence = "Mr. Green killed Colonel Mustard in the study with the " + \
           "candlestick. Mr. Green is not a very nice fellow."

print nltk.ngrams(sentence.split(), 2)
txt = nltk.Text(sentence.split())

txt.collocations()
# Out:
# <generator object ngrams at 0x0D201508>
# Mr. Green

# %% [markdown]
# # Example 12. Using NLTK to compute collocations in a similar manner to the nltk.Text.collocations demo functionality

# %%
import json
import nltk

# Load in human language data from wherever you've saved it
DATA = 'resources/ch04-googleplus/107033731246200681024.json'
data = json.loads(open(DATA).read())
print type(data)
# Number of collocations to find

N = 25

all_tokens = [token for activity in data for token in activity['object']['content'].lower().split()]

finder = nltk.BigramCollocationFinder.from_words(all_tokens)
finder.apply_freq_filter(2)
finder.apply_word_filter(lambda w: w in nltk.corpus.stopwords.words('english'))

scorer = nltk.metrics.association.BigramAssocMeasures.jaccard_distance
collocations = finder.nbest(scorer, N)

for collocation in collocations:
    c = ' '.join(collocation)
    print c
# Out:
# <type 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-a3e3fcdb0460> in <module>()
#      16 finder.apply_word_filter(lambda w: w in nltk.corpus.stopwords.words('english'))
#      17
# ---> 18 scorer = nltk.metrics.association.BigramAssocMeasures.jaccard_distance
#      19 collocations = finder.nbest(scorer, N)
#      20
#
# AttributeError: 'module' object has no attribute 'association'
